# %%
from matplotlib import pyplot as plt
import requests
import json 
import requests 
import matplotlib.pyplot as plt
import ipywidgets as w
from ipywidgets import interact
import numpy as np
from IPython.display import display, HTML, clear_output

# %%
welcometxt = w.HTML(
    value='<h1 style="text-align: center;">WELCOME! </h1>',
)

selection_text = w.HTML(
    value='<h1 style="text-align: center;">Please Log In or Sign Up </h1>',
)

show_LogIn = w.Button(description = "Log In",  disabled=False,
    button_style='info', 
    tooltip='Click me',)
show_signUp = w.Button(description = "Sign UP",  disabled=False,
    button_style='info', 
    tooltip='Click me',)

welcome_form = w.VBox([welcometxt, selection_text, w.HBox([show_LogIn, show_signUp])],layout=w.Layout(align_items='center'))
#FROM LOGIN & SIGNUP
eid = None
hid = None
position = None
#FROM LOGIN & SIGNUP
title = w.HTML(
    value='<h1 style="text-align: center;">DBSTRUGGLES ANALYTICS</h1>',
)

username_input = w.Text(   
    value='',
    placeholder='Username',
    disabled=False
    )
password_input = w.Password(   
    value='',
    placeholder='Password',
    disabled=False
    )
login_Button = w.Button(description = "Log In",  disabled=False,
    button_style='info', 
    tooltip='Click me',
)
login_form = w.VBox([title, username_input, password_input, login_Button] ,layout=w.Layout(align_items='center'))
login_form.layout.display = 'none'

    
greetingstxt = w.HTML(
    value='<h1 style="text-align: center;">GREETINGS! </h1>',
)
#______________________________________________________________________________________________________#


signup_hid_lbl = w.HTML(value='<b>Hotel ID: </b>', layout=w.Layout(width='200px', text_align='right'))
signup_hid_field =  w.IntText(
    value=0,
    disabled=False,
    layout=w.Layout(width='200px',border='1px solid black'))
signup_hid_box = w.HBox([signup_hid_lbl, signup_hid_field])
# Create the employee input fields for the sign up
instr = w.HTML(value='<h3>Fill the Required Fields</h3>', layout=w.Layout(width='400px', text_align='center'))

signup_fname_lbl = w.HTML(value='<b>First Name: </b>', layout=w.Layout(width='200px', text_align='right'))
signup_fname = w.Text(placeholder='First Name', layout=w.Layout(width='200px'))

signup_lname_lbl = w.HTML(value='<b>Last Name: </b>', layout=w.Layout(width='200px', text_align='right'))
signup_lname = w.Text(placeholder='Last Name', layout=w.Layout(width='200px'))

signup_age_lbl = w.HTML(value='<b>Age: </b>', layout=w.Layout(width='200px', text_align='right'))
signup_age = w.IntText(value=None, disabled=False, layout=w.Layout(width='200px'))

signup_position_lbl = w.HTML(value='<b>Position: </b>', layout=w.Layout(width='200px', text_align='right'))
signup_position = w.Dropdown(options=["Administrator", "Supervisor", "Regular"], description='', value=None, layout=w.Layout(width='200px'))

signup_salary_lbl = w.HTML(value='<b>Salary: </b>', layout=w.Layout(width='200px', text_align='right'))
signup_salary = w.FloatText(placeholder='Salary', layout=w.Layout(width='200px'))
return_button  = w.Button(description='Back', layout=w.Layout(margin='10px'), button_style='info')

# Combine labels and fields
signup_fname_box = w.HBox([signup_fname_lbl, signup_fname])
signup_lname_box = w.HBox([signup_lname_lbl, signup_lname])
signup_age_box = w.HBox([signup_age_lbl, signup_age])
signup_position_box = w.HBox([signup_position_lbl, signup_position])
signup_salary_box = w.HBox([signup_salary_lbl, signup_salary])
signup_create_employee_button = w.Button(description='Create Employeee', layout=w.Layout(margin='10px'), button_style='info')
sigup_empl_bottom_buttons = w.HBox([return_button,signup_create_employee_button], layout=w.Layout(align_items = 'center'))

# Create the form layout
signup_create_employee_form = w.VBox(
    [
        instr,
        signup_hid_box,
        signup_fname_box,
        signup_lname_box,
        signup_age_box,
        signup_position_box,
        signup_salary_box,
        sigup_empl_bottom_buttons
    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%')
)


# Display the form
signup_create_employee_form.layout.display = 'none'

#______________________________________________________________________________________________________#
#------------------------------------------------------------------------------------------------------------------------------------------------------------#


signup_eid_lbl = w.HTML(value='<b>Employee ID: </b>', layout=w.Layout(width='200px', text_align='right'))
signup_eid_field = w.IntText(value=None, disabled=False, layout=w.Layout(width='200px'))
# Combine labels and fields
signup_eid_box = w.HBox([signup_eid_lbl, signup_eid_field])
#CREATE  for SIGNUP
signup_login_username_lbl = w.HTML(value='<b>Username: </b>', layout=w.Layout(width='200px', text_align='right'))
signup_login_username = w.Text(placeholder='Username', layout=w.Layout(width='200px'))

# Create the password label
signup_login_password_lbl = w.HTML(value='<b>Password: </b>', layout=w.Layout(width='200px', text_align='right'))

# Create password and toggle widgets
signup_login_password = w.Password(placeholder='Enter your password', layout=w.Layout(width='200px'))
signup_plain_password = w.Text(value='', layout=w.Layout(width='200px', display='none'))
signup_password_toggle = w.ToggleButton(value=False, description='Show Password')

def signup_toggle_password_visibility(change):
    if change['new']:
        # Reveal password
        signup_login_password.layout.display = 'none'
        signup_plain_password.value = signup_login_password.value
        signup_password_toggle.layout.display = ''
    else:
        # Hide password
        signup_plain_password.layout.display = 'none'
        signup_login_password.value = signup_plain_password.value
        signup_login_password.layout.display = ''

# Link the toggle button to the password visibility function
signup_password_toggle.observe(signup_toggle_password_visibility, names='value')


sigup_login_username_box = w.HBox([signup_login_username_lbl, signup_login_username])
sigup_login_password_box = w.HBox([signup_login_password_lbl, signup_login_password])
signup_create_login_button = w.Button(description='Create Login', layout=w.Layout(margin='10px'), button_style='info')
signup_login_button =w.Button(description='Login', layout=w.Layout(margin='10px'), button_style='info')
sigup_bottom_buttons = w.HBox([signup_password_toggle, signup_create_login_button, signup_login_button], layout=w.Layout(align_items = 'center'))

signup_create_login_form = w.VBox(
    [
        instr,
        signup_eid_box,
        sigup_login_username_box,
        sigup_login_password_box,
        signup_plain_password,
        sigup_bottom_buttons,
    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%')
)

signup_create_login_form.layout.display = 'none'
#------------------------------------------------------------------------------------------------------------------------------------------------------------#
#______________________________________________________________________________________________________#

menu_create_reservation = w.Button(description = "MAKE A RESERVATION",  disabled=False,
    button_style='info', 
    tooltip='Click me',
     icon='solid plus',
     layout=w.Layout(width='200px', height='40px'),
     style=dict(button_color='#22dfb6', font_weight='bold'))
show_local_stats_regular = w.Button(description = "LOCAL STATS",  disabled=False,
    button_style='info', 
    tooltip='Click me',
    icon='solid plus',
    layout=w.Layout(width='200px', height='40px'),
     style=dict(button_color='#22dfb6', font_weight='bold'))

show_global_stats = w.Button(description = "GLOBAL STATS",  disabled=False,
    button_style='info', 
    tooltip='Click me',
    icon='solid plus',
    layout=w.Layout(width='200px', height='40px'),
     style=dict(button_color='#22dfb6', font_weight='bold'))

regular_options = w.VBox([greetingstxt, w.HBox([menu_create_reservation, show_local_stats_regular])],layout=w.Layout(align_items='center'))


create_unavailable_button = w.Button(description = "MARK A ROOM UNAVAILABLE",  disabled=False,
    button_style='info', 
    tooltip='Click me',
     icon='solid plus',
     layout=w.Layout(width='200px', height='40px'),
     style=dict(button_color='#22dfb6', font_weight='bold'))
show_local_stats = w.Button(description = "LOCAL STATS",  disabled=False,
    button_style='info', 
    tooltip='Click me',
    icon='solid plus',
    layout=w.Layout(width='200px', height='40px'),
     style=dict(button_color='#22dfb6', font_weight='bold'))


supervisor_options = w.VBox([greetingstxt, w.HBox([create_unavailable_button, show_local_stats])],layout=w.Layout(align_items='center'))
# Input for the room Id

select_entity = w.Dropdown(    
    options=["Chains", "Client", "Hotel", "Employee", "Login", "Reserve", "Room", "Room Description", "Room Unavailable"],
    placeholder="Choose a Record",
    description='Records:',
    value=None,
    layout = w.Layout(width = "300px")
)

select_txt = w.HTML(
    value='<h3 style="text-align: center;">Select the entity to create, update or delete a record </h3>')
# Create the button with an "X" icon
x_button = w.Button(
    icon='times',
    button_style='info',  # Unicode character for an X
    layout=w.Layout(width='40px', height='40px', border_radius='50%')
)
# Operation selection
operation_selection = w.RadioButtons(
    options=['POST', 'PUT', 'DELETE'],
    description='Operation:',
    disabled=False,
)

def hide_all_forms():
    forms = [
        create_chain_form, update_chain_form, delete_chain_form,
        create_client_form, update_client_form, delete_client_form,
        create_hotel_form, update_hotel_form, delete_hotel_form,
        create_employee_form, update_employee_form, delete_employee_form,
        create_login_form, update_login_form, delete_login_form,
        create_reserve_form, update_reserve_form, delete_reserve_form,
        create_room_form, update_room_form, delete_room_form,
        create_room_desc_form, update_description_form, delete_des_form,
        create_unavaibale_items, update_roomUnv_form, delete_roomUnv_form
        # Add other forms here...
    ]
    for form in forms:
        form.layout.display = 'none'


def clear_output(e):
    output.clear_output()
    hide_all_forms()
    global_nest.layout.display = 'none'
    tab_nest.layout.display = 'none'
    hid_form.layout.display = 'none'


x_button.on_click(clear_output)
admin_options = w.VBox(
    [greetingstxt, w.HBox([show_global_stats, show_local_stats, x_button]), select_txt, w.HBox([ select_entity, operation_selection], layout=w.Layout( justify_content='flex-end', align_items='center'))],
    layout=w.Layout(justify_content='center', align_items='center')  # Complete the layout argument
)
# Function to show the selected form
def toggle_form(change):
    hide_all_forms()
    operation = operation_selection.value
    entity = select_entity.value
    
    if entity == 'Chains':
        if operation == 'POST':
            create_chain_form.layout.display = 'flex'
        elif operation == 'PUT':
            update_chain_form.layout.display = 'flex'
        elif operation == 'DELETE':
            delete_chain_form.layout.display = 'flex'
    elif entity =='Client':
        if operation == 'POST':
            create_client_form.layout.display = 'flex'
        elif operation == 'PUT':
            update_client_form.layout.display = 'flex'
        elif operation == 'DELETE':
            delete_client_form.layout.display = 'flex'
    elif entity == "Hotel":
        if operation == 'POST':
            create_hotel_form.layout.display = 'flex'
        elif operation == "PUT":
            update_hotel_form.layout.display = 'flex'
        elif operation == "DELETE":
            delete_hotel_form.layout.display = 'flex'
    elif entity == 'Employee':
        if operation == 'POST':
            create_employee_form.layout.display = 'flex'
        elif operation == 'PUT':
            update_employee_form.layout.display = 'flex'
        elif operation == 'DELETE':
            delete_employee_form.layout.display = 'flex'
    elif entity == 'Login':
        if operation == 'POST':
            create_login_form.layout.display = 'flex'
        elif operation == 'PUT':
            update_login_form.layout.display = 'flex'
        elif operation == 'DELETE':
            delete_login_form.layout.display = 'flex'
    elif entity == 'Room':
        if operation == 'POST':
            create_room_form.layout.display = 'flex'
        elif operation == 'PUT':
            update_room_form.layout.display = 'flex'
        elif operation == 'DELETE':
            delete_room_form.layout.display = 'flex'
    elif entity == 'Room Description':
        if operation == 'POST':
            create_room_desc_form.layout.display = 'flex'
        elif operation == 'PUT':
            update_description_form.layout.display = 'flex'
        elif operation == 'DELETE':
            delete_des_form.layout.display = 'flex'
    elif entity == 'Room Unavailable':
        if operation == 'POST':
            create_unavaibale_items.layout.display = 'flex'
        elif operation == 'PUT':
            update_roomUnv_form.layout.display = 'flex'
        elif operation == 'DELETE':
            delete_roomUnv_form.layout.display = 'flex'
    elif entity == "Reserve":
        if operation == "POST":
            create_reserve_form.layout.display = 'flex'
        elif operation == "PUT":
            update_reserve_form.layout.display = 'flex'
        elif operation =='DELETE':
            delete_reserve_form.layout.display = 'flex'


operation_selection.observe(toggle_form, names='value')
select_entity.observe(toggle_form, names='value')


admin_options.layout.display = 'none'


#-------------------------------------------------------------------------------------------------------------------------

#-------------------------------------------------------------------------------------------------------------------------
regular_options.layout.display = 'none'
supervisor_options.layout.display = 'none'
admin_options.layout.display = 'none'


# Create an input widget for the ID
id_input = w.Text(
    value='',
    placeholder='Enter ID',
    description='ID:',
    disabled=False
) 
local_stats_inst = w.HTML(
    value='<h1 style="text-align: center;">Enter your Hotel ID </h1>',
)

# Create a button to confirm ID selection
confirm_button = w.Button(
    description='Submit',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click to submit ID',
    icon='check' # (FontAwesome names without the `fa-` prefix)
)
output = w.Output()
# Group the ID input and button together
hid_form =  w.VBox([local_stats_inst, w.HBox([id_input, confirm_button],  layout=w.Layout(justify_content='center', align_items='center'))])

hid_form.layout.display = 'none'

#------------------------------------------------------------------------------------------------------------------------------------------------------------#
# Create widgets for input fields
instr = w.HTML(value='<h3>Fill the Required Fields</h3>', layout=w.Layout(width='400px', text_align='center'))
chain_name_lbl = w.HTML(value='<b>Chain Name: </b>', layout=w.Layout(width='200px', text_align='right'))
cname_input = w.Text(placeholder='Chain Name', layout=w.Layout(width='200px', border='1px solid black'))
chain_spring_lbl = w.HTML(value='<b>Spring Markup: </b>', layout=w.Layout(width='200px', text_align='right'))
springmkup_input = w.FloatText(placeholder='Spring Markup', layout=w.Layout(width='200px', border='1px solid black'))
chain_summer_lbl = w.HTML(value='<b>Summer Markup: </b>', layout=w.Layout(width='200px', text_align='right'))
summermkup_input = w.FloatText(placeholder='Summer Markup', layout=w.Layout(width='200px', border='1px solid black'))
chain_fall_lbl = w.HTML(value='<b>Fall Markup: </b>', layout=w.Layout(width='200px', text_align='right'))
fallmkup_input = w.FloatText(placeholder='Fall Markup', layout=w.Layout(width='200px', border='1px solid black'))
chain_winter_lbl = w.HTML(value='<b>Winter Markup: </b>', layout=w.Layout(width='200px', text_align='right'))
wintermkup_input = w.FloatText(placeholder='Winter Markup', layout=w.Layout(width='200px', border='1px solid black'))

create_chain_button = w.Button(description='Create Chain', layout=w.Layout(margin='10px'), button_style='info')
cname_box = w.HBox([chain_name_lbl, cname_input])
spring_box = w.HBox([chain_spring_lbl, springmkup_input])
summer_box = w.HBox([chain_summer_lbl, summermkup_input])
fall_box = w.HBox([chain_fall_lbl, fallmkup_input])
winter_box = w.HBox([chain_winter_lbl, wintermkup_input])
# Create the form layout
create_chain_form = w.VBox(
    [
        instr,
        cname_box,
        spring_box,
        summer_box,
        fall_box,
        winter_box,
        create_chain_button
    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%'))

create_chain_form.layout.display= 'none'
#----------------------------------------------------------------#
#UPDATE CHAIN FORM
chid_label = w.HTML(value='<b>Chain ID: </b>', layout=w.Layout(width='200px', text_align='right'))
chid_field = w.IntText(
    value=0,
    disabled=False,
    layout=w.Layout(width='200px',border='1px solid black'))
chain_id_box = w.HBox([chid_label, chid_field])

update_chain_button = w.Button(description='Update Chain', layout=w.Layout(margin='10px'), button_style='info')
chain_info_button = w.Button(description='Get Chain Information', layout=w.Layout(margin='10px'), button_style='info')
option_chain_buttons = w.HBox([update_chain_button, chain_info_button], layout=w.Layout(align_items = 'center'))

update_chain_form = w.VBox(
    [
        instr,
        chain_id_box,
        cname_box,
        spring_box,
        summer_box,
        fall_box,
        winter_box,
        option_chain_buttons
    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%'))

update_chain_form.layout.display= 'none'
#------------------------------------------------------------------------------------------------------------------------------------------------------------#
#DELETE CHAIN  FORM
delete_instr =  w.HTML(value='<h3>Input the ID of the Chain to elete</h3>', layout=w.Layout(width='400px', text_align='center'))
delete_chain_button = w.Button(description='Delete Chain', layout=w.Layout(margin='10px'), button_style='info')

delete_chain_form = w.VBox(
    [
        instr,
        chain_id_box,
        delete_chain_button
    ],layout=w.Layout(justify_content='center', align_items='center', width='100%'))

delete_chain_form.layout.display =  'none'

#------------------------------------------------------------------------------------------------------------------------------------------------------------#
#------------------------------------------------------------------------------------------------------------------------------------------------------------#
#CREATE FOR CLIENT
client_fname_lbl = w.HTML(value='<b>First Name: </b>', layout=w.Layout(width='200px', text_align='right'))
client_fname = w.Text(placeholder='First Name', layout=w.Layout(width='200px', border='1px solid black'))
client_lname_lbl = w.HTML(value='<b>Last Name: </b>', layout=w.Layout(width='200px', text_align='right'))
client_lname = w.Text(placeholder='Last Name', layout=w.Layout(width='200px', border='1px solid black'))
client_age_lbl = w.HTML(value='<b>Age: </b>', layout=w.Layout(width='200px', text_align='right'))
client_age = w.IntText(
    value=0,  # Changed to integer as IntText expects an integer value
    disabled=False,
    layout=w.Layout(width='200px')
)
client_memyr_lbl = w.HTML(value='<b>Member Year:  </b>', layout=w.Layout(width='200px', text_align='right'))

client_memyr = w.IntText(
    value=0,
    disabled=False,
    layout=w.Layout(width='200px')
)


create_client_button = w.Button(description='Create Client', layout=w.Layout(margin='10px'), button_style='info')
client_fname_box = w.HBox([client_fname_lbl, client_fname])
client_lname_box = w.HBox([client_lname_lbl, client_lname])
client_age_box = w.HBox([client_age_lbl, client_age])
client_memeberyr_box = w.HBox([client_memyr_lbl, client_memyr])
# Create the form layout
create_client_form = w.VBox(
    [
        instr,
        client_fname_box,
        client_lname_box,
        client_age_box,
        client_memeberyr_box,
        create_client_button
    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%'))

create_client_form.layout.display = 'none'

#___________________________________________________________________________________________________________________________________________________________#
#UPDATE CLIENT FORM 
clid_label = w.HTML(value='<b>Client ID: </b>', layout=w.Layout(width='200px', text_align='right'))
clid_field = w.IntText(
    value=0,
    disabled=False,
    layout=w.Layout(width='200px',border='1px solid black'))
client_id_box = w.HBox([clid_label, clid_field])

update_client_button = w.Button(description='Update Client', layout=w.Layout(margin='10px'), button_style='info')
client_info_button = w.Button(description='Get Client Information', layout=w.Layout(margin='10px'), button_style='info')
option_client_buttons = w.HBox([update_client_button, client_info_button], layout=w.Layout(align_items = 'center'))

# Create the form layout
update_client_form = w.VBox(
    [
        instr,
        client_id_box,
        client_fname_box,
        client_lname_box,
        client_age_box,
        client_memeberyr_box,
        option_client_buttons
    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%'))

update_client_form.layout.display= 'none'
#------------------------------------------------------------------------------------------------------------------------------------------------------------#
#DELETE CLIENT
delete_client_button = w.Button(description='Delete Client', layout=w.Layout(margin='10px'), button_style='info')
delete_client_form = w.VBox(
    [
        delete_instr,
        client_id_box,
        delete_client_button
    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%'))

delete_client_form.layout.display= 'none'
#------------------------------------------------------------------------------------------------------------------------------------------------------------#
#------------------------------------------------------------------------------------------------------------------------------------------------------------#
#CREATE HOTEL FIELDS 
hname_lbl = w.HTML(value='<b>Hotel Name: </b>', layout=w.Layout(width='200px', text_align='right'))
hname_field = w.Text(placeholder='Hotel Name', layout=w.Layout(width='200px'))
hcity_lbl = w.HTML(value='<b>Hotel City: </b>', layout=w.Layout(width='200px', text_align='right'))
hcity_field = w.Text(placeholder='Hotel City', layout=w.Layout(width='200px'))
create_hotel_button = w.Button(description='Create Hotel', layout=w.Layout(margin='10px'), button_style='info')

hname_box = w.HBox([hname_lbl, hname_field])
hcity_box = w.HBox([hcity_lbl, hcity_field])
create_hotel_form = w.VBox(
    [
        instr,
        hname_box,
        chain_id_box,
        hcity_box,
        create_hotel_button
    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%'))
create_hotel_form.layout.display = 'none'


#------------------------------------------------------------------------------------------------------------------------------------------------------------#
#------------------------------------------------------------------------------------------------------------------------------------------------------------#
#UPDATE HOTEL FORM 
hid_lbl = w.HTML(value='<b>Hotel ID: </b>', layout=w.Layout(width='200px', text_align='right'))
hid_field =  w.IntText(
    value=0,
    disabled=False,
    layout=w.Layout(width='200px',border='1px solid black'))
hid_box = w.HBox([hid_lbl, hid_field])

hotel_info_button = w.Button(description='Get Hotel Information', layout=w.Layout(margin='10px'), button_style='info')
update_hotel_button = w.Button(description='Update Hotel', layout=w.Layout(margin='10px'), button_style='info')
hotel_option_buttons = w.HBox([update_hotel_button,hotel_info_button])
update_hotel_form = w.VBox(
    [
        instr,
        hid_box,
        hname_box,
        chain_id_box,
        hcity_box,
        hotel_option_buttons
    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%'))
update_hotel_form.layout.display = 'none'
#------------------------------------------------------------------------------------------------------------------------------------------------------------#
#------------------------------------------------------------------------------------------------------------------------------------------------------------#
#DELETE HOTEL
delete_hotel_button = w.Button(description='Delete Hotel', layout=w.Layout(margin='10px'), button_style='info')

delete_hotel_form = w.VBox([
    instr,
    hid_box,
    delete_hotel_button
],layout=w.Layout(justify_content='center', align_items='center', width='100%'))
delete_hotel_form.layout.display = 'none'
#------------------------------------------------------------------------------------------------------------------------------------------------------------#
#------------------------------------------------------------------------------------------------------------------------------------------------------------#
# Create the employee input fields
instr = w.HTML(value='<h3>Fill the Required Fields</h3>', layout=w.Layout(width='400px', text_align='center'))


employee_fname_lbl = w.HTML(value='<b>First Name: </b>', layout=w.Layout(width='200px', text_align='right'))
employee_fname = w.Text(placeholder='First Name', layout=w.Layout(width='200px'))

employee_lname_lbl = w.HTML(value='<b>Last Name: </b>', layout=w.Layout(width='200px', text_align='right'))
employee_lname = w.Text(placeholder='Last Name', layout=w.Layout(width='200px'))

employee_age_lbl = w.HTML(value='<b>Age: </b>', layout=w.Layout(width='200px', text_align='right'))
employee_age = w.IntText(value=None, disabled=False, layout=w.Layout(width='200px'))

employee_position_lbl = w.HTML(value='<b>Position: </b>', layout=w.Layout(width='200px', text_align='right'))
employee_position = w.Dropdown(options=["Administrator", "Supervisor", "Regular"], description='', value=None, layout=w.Layout(width='200px'))

employee_salary_lbl = w.HTML(value='<b>Salary: </b>', layout=w.Layout(width='200px', text_align='right'))
employee_salary = w.FloatText(placeholder='Salary', layout=w.Layout(width='200px'))

# Combine labels and fields
employee_fname_box = w.HBox([employee_fname_lbl, employee_fname])
employee_lname_box = w.HBox([employee_lname_lbl, employee_lname])
employee_age_box = w.HBox([employee_age_lbl, employee_age])
employee_position_box = w.HBox([employee_position_lbl, employee_position])
employee_salary_box = w.HBox([employee_salary_lbl, employee_salary])
create_employee_button = w.Button(description='Create Employeee', layout=w.Layout(margin='10px'), button_style='info')
# Create the form layout
create_employee_form = w.VBox(
    [
        instr,
        hid_box,
        employee_fname_box,
        employee_lname_box,
        employee_age_box,
        employee_position_box,
        employee_salary_box,
        create_employee_button
    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%')
)


# Display the form
create_employee_form.layout.display = 'none'
#------------------------------------------------------------------------------------------------------------------------------------------------------------#
#UPDATE EMPLOYEE

eid_lbl = w.HTML(value='<b>Employee ID: </b>', layout=w.Layout(width='200px', text_align='right'))
eid_field = w.IntText(value=None, disabled=False, layout=w.Layout(width='200px'))
# Combine labels and fields
eid_box = w.HBox([eid_lbl, eid_field])

employee_info_button = w.Button(description='Get Employee Information', layout=w.Layout(margin='10px'), button_style='info')
update_employee_button = w.Button(description='Update Employee', layout=w.Layout(margin='10px'), button_style='info')
employee_option_buttons = w.HBox([update_employee_button,employee_info_button])
update_employee_form = w.VBox(
    [
        instr,
        eid_box,
        hid_box,
        employee_fname_box,
        employee_lname_box,
        employee_age_box,
        employee_position_box,
        employee_salary_box,
        employee_option_buttons
    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%')
)


# Display the form
update_employee_form.layout.display = 'none'
#------------------------------------------------------------------------------------------------------------------------------------------------------------#
#DELETE EMPLOYEE
delete_employee_button = w.Button(description='Delete Employee', layout=w.Layout(margin='10px'), button_style='info')
delete_employee_form = w.VBox(
    [
        instr,
        eid_box,
        delete_employee_button

    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%')
)


delete_employee_form.layout.display = 'none'

#------------------------------------------------------------------------------------------------------------------------------------------------------------#
#CREATE LOGIN
login_username_lbl = w.HTML(value='<b>Username: </b>', layout=w.Layout(width='200px', text_align='right'))
login_username = w.Text(placeholder='Username', layout=w.Layout(width='200px'))

# Create the password label
login_password_lbl = w.HTML(value='<b>Password: </b>', layout=w.Layout(width='200px', text_align='right'))

# Create password and toggle widgets
login_password = w.Password(placeholder='Enter your password', layout=w.Layout(width='200px'))
plain_password = w.Text(value='', layout=w.Layout(width='200px', display='none'))
password_toggle = w.ToggleButton(value=False, description='Show Password')

def toggle_password_visibility(change):
    if change['new']:
        # Reveal password
        login_password.layout.display = 'none'
        plain_password.value = login_password.value
        plain_password.layout.display = ''
    else:
        # Hide password
        plain_password.layout.display = 'none'
        login_password.value = plain_password.value
        login_password.layout.display = ''

# Link the toggle button to the password visibility function
password_toggle.observe(toggle_password_visibility, names='value')


login_username_box = w.HBox([login_username_lbl, login_username])
login_password_box = w.HBox([login_password_lbl, login_password])
create_login_button = w.Button(description='Create Login', layout=w.Layout(margin='10px'), button_style='info')
bottom_buttons = w.HBox([password_toggle, create_login_button], layout=w.Layout(align_items = 'center'))

create_login_form = w.VBox(
    [
        instr,
        eid_box,
        login_username_box,
        login_password_box,
        plain_password,
        bottom_buttons,
    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%')
)

create_login_form.layout.display = 'none'
#------------------------------------------------------------------------------------------------------------------------------------------------------------#
#UPDATE LOGIN

lid_lbl = w.HTML(value='<b>Login ID: </b>', layout=w.Layout(width='200px', text_align='right'))
lid_field = w.IntText(value=None, disabled=False, layout=w.Layout(width='200px'))
# Combine labels and fields
lid_box = w.HBox([lid_lbl, lid_field])


update_login_button = w.Button(description='Update Login', layout=w.Layout(margin='10px'), button_style='info')
login_info_button = w.Button(description='Get Login Information', layout=w.Layout(margin='10px'), button_style='info')
login_option_buttons = w.HBox([password_toggle,update_login_button,login_info_button],layout = w.Layout(align_items='center') )
update_login_form = w.VBox(
    [
        instr,
        lid_box,
        eid_box,
        login_username_box,
        login_password_box,
        plain_password,
        login_option_buttons

    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%')
)


# Display the form
update_login_form.layout.display = 'none'
#------------------------------------------------------------------------------------------------------------------------------------------------------------#
#DELETE LOGIN
delete_login_button = w.Button(description='Delete Login', layout=w.Layout(margin='10px'), button_style='info')
delete_login_form = w.VBox(
    [
        instr,
        lid_box,
        delete_login_button

    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%')
)


delete_login_form.layout.display = 'none'

#------------------------------------------------------------------------------------------------------------------------------------------------------------#

#------------------------------------------------------------------------------------------------------------------------------------------------------------#
# CREATE ROOM DESCRIPTION
room_name_lbl = w.HTML(value='<b>Room Name: </b>', layout=w.Layout(width='200px', text_align='right'))
room_name_field = w.Dropdown(
    options=["Standard", "Standard Queen", "Standard King", "Double Queen", "Double King", "Triple King", "Executive Family", "Presidential"],
    description='',
    value=None,
    layout=w.Layout(width='200px')
)

room_type_lbl = w.HTML(value='<b>Room Type: </b>', layout=w.Layout(width='200px', text_align='right'))
room_type_field = w.Dropdown(description='', value=None, layout=w.Layout(width='200px'))

capacity_lbl = w.HTML(value='<b>Capacity: </b>', layout=w.Layout(width='200px', text_align='right'))
capacity_field = w.Dropdown(description='', value=None, layout=w.Layout(width='200px'))

handicap_lbl = w.HTML(value='<b>Handicap: </b>', layout=w.Layout(width='200px', text_align='end '))
handicap_field = w.Checkbox(value=False, disabled=False, indent=False)

room_options = {
    "Standard": {1: ["Basic", "Premium"]},
    "Standard Queen": {1: ["Basic", "Premium", "Deluxe"], 2: ["Basic", "Premium", "Deluxe"]},
    "Standard King": {2: ["Basic", "Premium", "Deluxe"]},
    "Double Queen": {4: ["Basic", "Premium", "Deluxe"]},
    "Double King": {4: ["Basic", "Premium", "Deluxe", "Suite"], 6: ["Basic", "Premium", "Deluxe", "Suite"]},
    "Triple King": {6: ["Deluxe", "Suite"]},
    "Executive Family": {4: ["Deluxe", "Suite"], 6: ["Deluxe", "Suite"], 8: ["Deluxe", "Suite"]},
    "Presidential": {4: ["Suite"], 6: ["Suite"], 8: ["Suite"]}
}

def update_capacity_and_room_types(*args):
    room_name = room_name_field.value
    if room_name in room_options:
        capacities = list(room_options[room_name].keys())
        capacity_field.options = capacities
        # Set the first capacity as default
        capacity_field.value = capacities[0] if capacities else None
        update_room_types()

def update_room_types(*args):
    room_name = room_name_field.value
    capacity = capacity_field.value
    if room_name in room_options and capacity in room_options[room_name]:
        room_type_field.options = room_options[room_name][capacity]
    else:
        room_type_field.options = []

# Link the room name field to update the capacity options
room_name_field.observe(update_capacity_and_room_types, names='value')
# Link the capacity field to update the room types
capacity_field.observe(update_room_types, names='value')

# Combine labels and fields
room_name_box = w.HBox([room_name_lbl, room_name_field],layout=w.Layout(align_items='center'))
capacity_box = w.HBox([capacity_lbl, capacity_field],layout=w.Layout(align_items='center'))
room_type_box = w.HBox([room_type_lbl, room_type_field],layout=w.Layout(align_items='center'))
handicap_box = w.HBox([handicap_lbl, handicap_field], layout=w.Layout(align_items='center', margin='0px 0px 0px 100px'))
create_room_desc_button = w.Button(description='Create Room Description', layout=w.Layout(margin='10px'), button_style='info')
create_room_desc_form = w.VBox(
    [
        room_name_box,
        capacity_box,
        room_type_box,
        handicap_box,
        create_room_desc_button
    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%')
)

create_room_desc_form.layout.display ='none'
#-------------------------------------------------------------------------------------------------------------------------------------------------------#
#UPDATE ROOM DESC

room_des_lbl = w.HTML(value='<b>Room Description ID: </b>', layout=w.Layout(width='200px', text_align='right'))
rdid_field = w.IntText(value=None, disabled=False, layout=w.Layout(width='200px'))

rdid_box = w.HBox([room_des_lbl, rdid_field])
update_description_button = w.Button(description='Update Room Description', layout=w.Layout(margin='10px'), button_style='info')
description_info_button = w.Button(description='Get Room Description', layout=w.Layout(margin='10px'), button_style='info')
description_option_buttons = w.HBox([update_description_button,description_info_button])
update_description_form = w.VBox(
    [
        instr,
        rdid_box,
        room_name_box,
        capacity_box,
        room_type_box,
        handicap_box,
        description_option_buttons

    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%')
)


# Display the form
update_description_form.layout.display = 'none'
#------------------------------------------------------------------------------------------------------------------------------------------------------------#
#DELETE ROOM DESCRIPTION
delete_des_button = w.Button(description='Delete Room Description', layout=w.Layout(margin='10px'), button_style='info')
delete_des_form = w.VBox(
    [
        instr,
        rdid_box,
        delete_des_button

    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%')
)


delete_des_form.layout.display = 'none'


#------------------------------------------------------------------------------------------------------------------------------------------------------------#

# CREATE ROOM 
room_des_lbl = w.HTML(value='<b>Room Description: </b>', layout=w.Layout(width='200px', text_align='right'))
room_des_field = w.IntText(value=None, disabled=False, layout=w.Layout(width='200px'))
room_price_lbl = w.HTML(value='<b>Room Price: </b>', layout=w.Layout(width='200px', text_align='right'))
room_price_field = w.FloatText(placeholder="Room Price", layout=w.Layout(width='200px', border='1px solid black'))


# Combine labels and fields
room_hid_box = w.HBox([hid_lbl, hid_field],layout=w.Layout(align_items='center'))
room_des_box = w.HBox([room_des_lbl, room_des_field],layout=w.Layout(align_items='center'))
room_price_box = w.HBox([room_price_lbl, room_price_field],layout=w.Layout(align_items='center'))
create_room_button = w.Button(description='Create Room', layout=w.Layout(margin='10px'), button_style='info')
create_room_form = w.VBox(
    [
        instr,
        room_hid_box,
        room_des_box,
        room_price_box,
        create_room_button,
    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%')
)

create_room_form.layout.display ='none'
#-------------------------------------------------------------------------------------------------------------------------------------------------------#
#UPDATE ROOM


rid_lbl = w.HTML(value='<b>Room ID: </b>', layout=w.Layout(width='200px', text_align='right'))
rid_field = w.IntText(value=None, disabled=False, layout=w.Layout(width='200px'))

rid_box = w.HBox([rid_lbl, rid_field])
update_room_button = w.Button(description='Update Room', layout=w.Layout(margin='10px'), button_style='info')
room_info_button = w.Button(description='Get Room Information', layout=w.Layout(margin='10px'), button_style='info')
room_option_buttons = w.HBox([update_room_button,room_info_button])
update_room_form = w.VBox(
    [
        instr,
        rid_box,
        room_hid_box,
        room_des_box,
        room_price_box,
        room_option_buttons,

    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%')
)


# Display the form
update_room_form.layout.display = 'none'
#-------------------------------------------------------------------------------------------------------------------------------------------------------#
#DELETE ROOM UNV
delete_room_button = w.Button(description='Delete Room', layout=w.Layout(margin='10px'), button_style='info')
delete_room_form = w.VBox(
    [
        instr,
        rid_box,
        delete_room_button

    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%')
)


delete_room_form.layout.display = 'none'

#-------------------------------------------------------------------------------------------------------------------------------------------------------#

#CREATE ROOM UNAVAILABLE
start_lbl = w.HTML(value='<b>Start Date: </b>', layout=w.Layout(width='200px', text_align='right'))

startdate_input = w.DatePicker(
    disabled=False,
    layout=w.Layout(width='200px')
)
end_lbl = w.HTML(value='<b>End Date: </b>', layout=w.Layout(width='200px', text_align='right'))

endate_input = w.DatePicker(

    disabled=False,
    layout=w.Layout(width='200px')
)

start_date_hbox = w.HBox([start_lbl, startdate_input])
end_date_hbox = w.HBox([end_lbl, endate_input])

create_unavailable_button_confirm = w.Button(description='Create Room Unavailable', layout=w.Layout(margin='10px'), button_style='info')

create_unavaibale_items = w.VBox(
    [
        instr,
        rid_box,
        start_date_hbox,
        end_date_hbox,
        create_unavailable_button_confirm
    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%')
)

create_unavaibale_items.layout.display = 'none'
#-------------------------------------------------------------------------------------------------------------------------------------------------------#
#UPDATE ROOM UNV


ruid_lbl = w.HTML(value='<b>Room Unavailable </b>', layout=w.Layout(width='200px', text_align='right'))
ruid_field = w.IntText(value=None, disabled=False, layout=w.Layout(width='200px'))

ruid_box = w.HBox([ruid_lbl, ruid_field])
update_roomUnv_button = w.Button(description='Update Room Unavailable', layout=w.Layout(margin='10px'), button_style='info')
roomUn_info_button = w.Button(description='Get Room Unavailable', layout=w.Layout(margin='10px'), button_style='info')
roomUn_option_buttons = w.HBox([update_roomUnv_button,roomUn_info_button])
update_roomUnv_form = w.VBox(
    [
        instr,
        ruid_box,
        rid_box,
        start_date_hbox,
        end_date_hbox,
        roomUn_option_buttons,

    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%')
)


# Display the form
update_roomUnv_form.layout.display = 'none'
#-------------------------------------------------------------------------------------------------------------------------------------------------------#
delete_roomUnv_button = w.Button(description='Delete Room Unavailable', layout=w.Layout(margin='10px'), button_style='info')
delete_roomUnv_form = w.VBox(
    [
        instr,
        ruid_box,
        delete_roomUnv_button

    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%')
)


delete_roomUnv_form.layout.display = 'none'

#-------------------------------------------------------------------------------------------------------------------------------------------------------#
#CREATE RESERVE FORM 

reserve_start_lbl = w.HTML(value='<b>Start Date: </b>', layout=w.Layout(width='200px', text_align='right'))

reserve_startdate_input = w.DatePicker(
    disabled=False,
    layout=w.Layout(width='200px')
)
reserve_end_lbl = w.HTML(value='<b>End Date: </b>', layout=w.Layout(width='200px', text_align='right'))

reserve_endate_input = w.DatePicker(

    disabled=False,
    layout=w.Layout(width='200px')
)

reserve_start_date_hbox = w.HBox([reserve_start_lbl, reserve_startdate_input])
reserve_end_date_hbox = w.HBox([reserve_end_lbl, reserve_endate_input])

reserve_guest_lbl =  w.HTML(value='<b>Number of Guest: </b>', layout=w.Layout(width='200px', text_align='right'))

reserve_hid_lbl = w.HTML(value='<b>Hotel ID: </b>', layout=w.Layout(width='200px', text_align='right'))
reserve_hid_field = w.IntText(value=None, disabled=False, layout=w.Layout(width='200px'))
reserve_hid_hbox = w.HBox([reserve_hid_lbl, reserve_hid_field])

reserve_guest_field = w.IntText(value=None, disabled=False, layout=w.Layout(width='200px'))
guest_hbox = w.HBox([reserve_guest_lbl, reserve_guest_field])
reserve_handicap_lbl = w.HTML(value='<b>Handicap: </b>', layout=w.Layout(width='200px', text_align='end '))
reserve_handicap_field = w.Checkbox(value=False, disabled=False, indent=False)
reserve_handicap_box = w.HBox([reserve_handicap_lbl, reserve_handicap_field], layout=w.Layout(align_items='center', margin='0px 0px 0px 100px'))
available_rooms_lbl = w.HTML(value='<b>Available Rooms: </b>', layout=w.Layout(width='200px', text_align='end '))
available_rooms_select = w.Dropdown(description='', value=None, layout=w.Layout(width='200px'))
check_available_button = w.Button(description='Check Availability', layout=w.Layout(margin='10px'), button_style='info')
available_box =  w.HBox([available_rooms_lbl, available_rooms_select])


reserve_client_lbl = w.HTML(value='<b>Client ID: </b>', layout=w.Layout(width='200px', text_align='end '))
reserve_client_field = w.IntText(value=None, disabled=False, layout=w.Layout(width='200px'))
reserve_payment_lbl = w.HTML(value='<b>Payment: </b>', layout=w.Layout(width='200px', text_align='end '))
payment_select = w.Dropdown(options=["credit card", "debit card", "cash", "check", "pear pay"], value=None, layout=w.Layout(width='200px'))

reserve_client_hbox = w.HBox([reserve_client_lbl, reserve_client_field])
reserve_payment_hbox = w.HBox([reserve_payment_lbl, payment_select])


reserve_room_button =  w.Button(description='Reserve Room', layout=w.Layout(margin='10px'), button_style='info')

def on_room_select(change):
    if change['new'] is not None:
        reserve_room_button.layout.display = 'inline-block'
        reserve_client_hbox.layout.display = 'inline-block'
        reserve_payment_hbox.layout.display = 'inline-block'
    else:
        reserve_room_button.layout.display = 'none'
        reserve_client_hbox.layout.display = 'none'
        reserve_payment_hbox.layout.display = 'none'

available_rooms_select.observe(on_room_select, names='value')
reserve_room_button.layout.display = 'none'
reserve_client_hbox.layout.display = 'none'
reserve_payment_hbox.layout.display = 'none'


create_reserve_form = w.VBox(
    [
        instr,
        guest_hbox,
        reserve_start_date_hbox,
        reserve_end_date_hbox,
        reserve_handicap_box,
        reserve_hid_hbox,
        available_box,
        check_available_button,
        reserve_client_hbox,
        reserve_payment_hbox,
        reserve_room_button
    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%')
)
available_box.layout.display = 'none'
create_reserve_form.layout.display = 'none'
#-------------------------------------------------------------------------------------------------------------------------------------------------------#
#-------------------------------------------------------------------------------------------------------------------------------------------------------#
# CREATE EMPLOYEE FORM FOR REGULAR (NO INPUT FOR HOTEL) 

employee_start_lbl = w.HTML(value='<b>Start Date: </b>', layout=w.Layout(width='200px', text_align='right'))

employee_startdate_input = w.DatePicker(
    disabled=False,
    layout=w.Layout(width='200px')
)
employee_end_lbl = w.HTML(value='<b>End Date: </b>', layout=w.Layout(width='200px', text_align='right'))

employee_enddate_input = w.DatePicker(
    disabled=False,
    layout=w.Layout(width='200px')
)

employee_start_date_hbox = w.HBox([employee_start_lbl, employee_startdate_input])
employee_end_date_hbox = w.HBox([employee_end_lbl, employee_enddate_input])

employee_guest_lbl = w.HTML(value='<b>Number of Guests: </b>', layout=w.Layout(width='200px', text_align='right'))


employee_guest_field = w.IntText(value=None, disabled=False, layout=w.Layout(width='200px'))
employee_guest_hbox = w.HBox([employee_guest_lbl, employee_guest_field])
employee_handicap_lbl = w.HTML(value='<b>Handicap: </b>', layout=w.Layout(width='200px', text_align='end '))
employee_handicap_field = w.Checkbox(value=False, disabled=False, indent=False)
employee_handicap_box = w.HBox([employee_handicap_lbl, employee_handicap_field], layout=w.Layout(align_items='center', margin='0px 0px 0px 100px'))
empl_rooms_lbl = w.HTML(value='<b>Available Rooms: </b>', layout=w.Layout(width='200px', text_align='end '))


empl_rooms_select = w.Dropdown(description='', value=None, layout=w.Layout(width='200px'))
empl_available_button = w.Button(description='Check Availability', layout=w.Layout(margin='10px'), button_style='info')
empl_available_box = w.HBox([empl_rooms_lbl, empl_rooms_select])

employee_client_lbl = w.HTML(value='<b>Client ID: </b>', layout=w.Layout(width='200px', text_align='end '))
employee_client_field = w.IntText(value=None, disabled=False, layout=w.Layout(width='200px'))
employee_payment_lbl = w.HTML(value='<b>Payment: </b>', layout=w.Layout(width='200px', text_align='end '))
empl_payment_select = w.Dropdown(options=["credit card", "debit card", "cash", "check", "pear pay"], value=None, layout=w.Layout(width='200px'))

employee_client_hbox = w.HBox([employee_client_lbl, employee_client_field])
employee_payment_hbox = w.HBox([employee_payment_lbl, empl_payment_select])

employee_room_button = w.Button(description='Reserve Room', layout=w.Layout(margin='10px'), button_style='info')

def on_room_select(change):
    if change['new'] is not None:
        employee_room_button.layout.display = 'inline-block'
        employee_client_hbox.layout.display = 'inline-block'
        employee_payment_hbox.layout.display = 'inline-block'
    else:
        employee_room_button.layout.display = 'none'
        employee_client_hbox.layout.display = 'none'
        employee_payment_hbox.layout.display = 'none'

empl_rooms_select.observe(on_room_select, names='value')
employee_room_button.layout.display = 'none'
employee_client_hbox.layout.display = 'none'
employee_payment_hbox.layout.display = 'none'

create_regular_reserve_form = w.VBox(
    [
        instr,
        employee_guest_hbox,
        employee_start_date_hbox,
        employee_end_date_hbox,
        employee_handicap_box,
        empl_available_box,
        empl_available_button,
        employee_client_hbox,
        employee_payment_hbox,
        employee_room_button
    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%')
)
empl_available_box.layout.display = 'none'
create_regular_reserve_form.layout.display = 'none'
#-------------------------------------------------------------------------------------------------------------------------------------------------------#
#UPDATE RESERVE
reid_label = w.HTML(value='<b>Reservation ID: </b>', layout=w.Layout(width='200px', text_align='end '))
reid_field = w.IntText(value=None, disabled=False, layout=w.Layout(width='200px'))

cost_lbl = w.HTML(value='<b>Total Cost: </b>', layout=w.Layout(width='200px', text_align='end '))
cost_field = w.FloatText(value=None, disabled=False, layout=w.Layout(width='200px'))

reid_hbox = w.HBox([reid_label, reid_field])


update_client_lbl = w.HTML(value='<b>Client ID: </b>', layout=w.Layout(width='200px', text_align='end '))
update_client_field = w.IntText(value=None, disabled=False, layout=w.Layout(width='200px'))
update_reserve_client_hbox = w.HBox([update_client_lbl, update_client_field])

update_payment_lbl = w.HTML(value='<b>Payment: </b>', layout=w.Layout(width='200px', text_align='end '))
update_payment_select = w.Dropdown(options=["credit card", "debit card", "cash", "check", "pear pay"], value=None, layout=w.Layout(width='200px'))

update_payment_hbox = w.HBox([update_payment_lbl, update_payment_select])

reserve_cost_hbox = w.HBox([cost_lbl, cost_field])
update_reserve_button = w.Button(description='Update Reserve', layout=w.Layout(margin='10px'), button_style='info')
reserve_info_button = w.Button(description='Get Reservation', layout=w.Layout(margin='10px'), button_style='info')
reserve_option_buttons = w.HBox([update_reserve_button,reserve_info_button])
update_reserve_form = w.VBox(
    [
        instr,
        reid_hbox,
        update_reserve_client_hbox,
        ruid_box,
        reserve_cost_hbox,
        update_payment_hbox,
        guest_hbox,
        reserve_option_buttons
    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%')
)
update_reserve_form.layout.display = 'none'

#-------------------------------------------------------------------------------------------------------------------------------------------------------#
#DELETE RESERVE
delete_reserve_button = w.Button(description='Delete Reserve', layout=w.Layout(margin='10px'), button_style='info')
delete_reserve_form = w.VBox(
    [
        instr,
        reid_hbox,
        delete_reserve_button

    ],
    layout=w.Layout(justify_content='center', align_items='center', width='100%')
)


delete_reserve_form.layout.display = 'none'
#-------------------------------------------------------------------------------------------------------------------------------------------------------#
#-------------------------------------------------------------------------------------------------------------------------------------------------------#
tab_nest = w.Tab()
global_nest = w.Tab()
# Function to create tabs for local stats
def global_tabs(event):
    hid_form.layout.display = 'none'
    tab_nest.layout.display = 'none'
    global eid
    try:
        output.clear_output()
        admin_eid = eid
        rev = fetch_revenue_data(admin_eid)
        payment = fetch_payment_method(admin_eid)
        rooms = fetch_least_rooms(admin_eid)
        capacity = fetch_most_capacity_data(admin_eid)
        reservations = fetch_most_reservations(admin_eid)
        profit = fetch_most_profit_month(admin_eid)

        contents = [
            " Top 3 chains with the highest total revenue ",
            "Total reservation percentage by payment method",
            "Top 3 hotel’s chain with the least rooms.",
            " Top 5 hotels with the most client capacity",
            "Top 10% of the hotels that had the most reservations",
            "Top 3 month with the most reservation by chain"
        ]

        nest_children = [w.Output(layout={'border': '1px solid black'}) if i in [0, 1 ,2, 3, 4, 5] else w.Label(value=content)
            for i, content in enumerate(contents)]
        global_nest.children =nest_children

        global_nest.set_title(0, "Handicap Rooms")
        global_nest.set_title(1, "Payment Methods")
        global_nest.set_title(2, "Least Rooms")
        global_nest.set_title(3, "Most Capacity")
        global_nest.set_title(4, "Most Reservations")
        global_nest.set_title(5, "Months with Most Reservations by Chain")
        if rev:
            with nest_children[0]:
                plot_revenue_data(rev)
        if payment:
            with nest_children[1]:
                plot_payment(payment)
        if rooms:
            with nest_children[2]:
                plot_least_rooms(rooms)
        if capacity:
            with nest_children[3]:
                plot_most_capacity(capacity)
        if reservations:
            with nest_children[4]:
                plot_most_reservations(reservations)
        if profit:
            with nest_children[5]:
                plot_most_profit(profit)


        global_nest.layout.display = ''  # Make the tabs visible

        # Hide initial forms and display the tabs
        welcome_form.layout.display = 'none'
        login_form.layout.display = 'none'
        regular_options.layout.display = 'none'

    except Exception as e:
        with output:
            print(f"Error occurred: {str(e)}")

global_nest.layout.display = 'none'    

def create_tabs(event):
    global eid
    try:
        output.clear_output()
        selected_id = id_input.value

        # Fetch data for the tabs
        isHandicap = fetch_handicap_stat(selected_id, eid)
        leastReserve = fetch_least_reserve(selected_id, eid)
        credit_cards = fetch_credit_cards(selected_id, eid)
        highest_paid = fetch_highest_paid(selected_id, eid)
        discount = fetch_most_discounts(selected_id, eid)
        room_type = fetch_reserv_type(selected_id, eid)
        ratio = fetch_ratio(selected_id, eid)

        # Create tab contents
        tab_contents = [
            "Top 5 Handicap Rooms",
            "Top 3 Least Time Unavailable",
            "Top 5 Clients/Credit Card",
            "Top 5 Highest Paid Employees",
            "Top 5 Clients With Most Discounts",
            "Total reservation by room type",
            "Top 3 rooms that were reserved that had the least guest-to-capacity ratio"
        ]

        # Create widgets for each tab content
        tab_children = [
            w.Output(layout={'border': '1px solid black'}) if i in [0, 1, 2, 3, 4, 5,6] else w.Label(value=content)
            for i, content in enumerate(tab_contents)
        ]

        # Assign children to tabs
        tab_nest.children = tab_children

        # Setting tab titles
        tab_nest.set_title(0, "Handicap Rooms")
        tab_nest.set_title(1, "Least Time Unavailable")
        tab_nest.set_title(2, "Most Credit Cards")
        tab_nest.set_title(3, "Highest Paid Employees")
        tab_nest.set_title(4, "Most Discounts")
        tab_nest.set_title(5, "Reservations by room type")
        tab_nest.set_title(6, "Least guest-to-capacity ratio")

        # Plot reservation counts in the first tab
        if isHandicap:
            with tab_children[0]:
                plot_reservation_counts(isHandicap, selected_id)

        # Plot least reserved rooms in the second tab
        if leastReserve:
            with tab_children[1]:
                plot_least_reserve(leastReserve, selected_id)

        # Plot credit card usage in the third tab
        if credit_cards:
            with tab_children[2]:
                plot_credit_cards(credit_cards, selected_id)

        # Plot highest paid employees in the fourth tab
        if highest_paid:
            with tab_children[3]:
                plot_highest_paid(highest_paid, selected_id)
        
        # Plot clients with most discounts in the fifth tab
        if discount:
            with tab_children[4]:
                plot_most_discount(discount, selected_id)

        if room_type:
            with tab_children[5]:
                plot_reserv_type(room_type, selected_id)
               
        if ratio:
            with tab_children[6]:
                plot_ratio(ratio, selected_id)
        # Show the tab_nest
        tab_nest.layout.display = ''  # Make the tab_nest visible

        # Hide initial forms and display the tabs
        welcome_form.layout.display = 'none'
        login_form.layout.display = 'none'

    except Exception as e:
        with output:
            print(f"Error occurred: {str(e)}")

tab_nest.layout.display = 'none'

# %%
def create_chain(e):
    output.clear_output()
    cname = cname_input.value
    springmkup = springmkup_input.value
    summermkup = summermkup_input.value
    fallmkup = fallmkup_input.value
    wintermkup = wintermkup_input.value
    data = {
            'cname': cname,
            'springmkup': springmkup,
            'summermkup': summermkup,
            'fallmkup': fallmkup,
            'wintermkup': wintermkup
        }
    json_data = json.dumps(data)
    with output:
        url = "https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/chains"
        headers = {'Content-Type': 'application/json'}
        
        response = requests.post(url, data=json_data, headers=headers)
        if response.status_code == 201:
            response = response.json()
            chid = response['chid']
            create_chain_form.layout.display = 'none'
            output.clear_output()
            print("Chain ID: ", chid)
            print("Chain Name: ", cname)
            print("Spring Markup: ", springmkup)
            print("Summer Markup: ", summermkup)
            print("Fall Markup: ", fallmkup)
            print("Winter Markup: ", wintermkup)
            print('Chain Created')
        else:
            # Print error message if request was unsuccessful
            print( response.text)
            print('Failed to create chain')
#UPDATE CHAIN 
def fetch_chain_byId(e):
    chain_id = chid_field.value
    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/chains/{chain_id}"
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            cname = data['cname']
            springmkup = data['springmkup']
            summermkup = data['summermkup']
            fallmkup = data['fallmkup']
            wintermkup = data['wintermkup']
            output.clear_output()
            print('Chain Information')
            print("Chain ID: ", chain_id)
            print("Chain Name: ", cname)
            print("Spring Markup: ", springmkup)
            print("Summer Markup: ", summermkup)
            print("Fall Markup: ", fallmkup)
            print("Winter Markup: ", wintermkup)
            
        else:
            print(f"Chain with ID {chain_id} not found.")

def update_chain(e):
    chain_id = chid_field.value
    cname = cname_input.value
    springmkup = springmkup_input.value
    summermkup = summermkup_input.value
    fallmkup = fallmkup_input.value
    wintermkup = wintermkup_input.value

    data = {
            "chid": chain_id,
            'cname': cname,
            'springmkup': springmkup,
            'summermkup': summermkup,
            'fallmkup': fallmkup,
            'wintermkup': wintermkup
        }
    json_data = json.dumps(data)

    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/chains/{chain_id}"
        headers = {'Content-Type': 'application/json'}
        
        response = requests.put(url, data=json_data, headers=headers)
        if response.status_code == 200:
            response = response.json()
            chid = response['chid']
            update_chain_form.layout.display = 'none'
            output.clear_output()
            print("Chain ID: ", chid)
            print("Chain Name: ", cname)
            print("Spring Markup: ", springmkup)
            print("Summer Markup: ", summermkup)
            print("Fall Markup: ", fallmkup)
            print("Winter Markup: ", wintermkup)
            print('Chain Updated')
        else:
            # Print error message if request was unsuccessful
            print(response.text)
            print('Failed to update chain')
    

def delete_chain(e):
    chain_id = chid_field.value

    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/chains/{chain_id}"
        headers = {'Content-Type': 'application/json'}
        
        response = requests.delete(url)
        if response.status_code == 200:
            response = response.json()
            delete_chain_form.layout.display = 'none'
            output.clear_output()
            print(f'Chain {chain_id} Deleted' )
        else:
            # Print error message if request was unsuccessful
            print(response.text)
            print('Failed to delete chain')
#_______________________________________________________________________________________________#
#CREATE CLIENT
def create_client(e):
    output.clear_output()
    fname = client_fname.value
    lname = client_lname.value
    age = client_age.value
    memyr = client_memyr.value

    data = {
        "age": age,
        "fname": fname,
        "lname": lname,
        "memberyear": memyr
    }
    json_data = json.dumps(data)
    url = "https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/client"
    headers = {'Content-Type': 'application/json'}
    with output:
        response = requests.post(url, data=json_data, headers=headers)
        if response.status_code == 201:
            response = response.json()
            clid = response['clid']
            create_client_form.layout.display = 'none'
            output.clear_output()
            print('Client ID: ', clid)
            print("First Name: ", fname )
            print("Last Name: ", lname)
            print("Age: ", age)
            print("Memeber Year: ", memyr)
            print('Client Created')
        else:
            print( response.text)
            print('Failed to create client')

#UPDATE CLIENT

def fetch_client_byId(e):
    client = clid_field.value
    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/client/{client}"
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            fname = data['fname']
            lname = data['lname']
            age = data['age']
            memberyear = data['memberyear']
            output.clear_output()
            print('Client Information')
            print('Client ID: ', client)
            print("First Name: ", fname )
            print("Last Name: ", lname)
            print("Age: ", age)
            print("Memeber Year: ", memberyear)
        else:
            print(f"Client with ID {client} not found.")
def update_client(e):
    client = clid_field.value
    fname = client_fname.value
    lname = client_lname.value
    age = client_age.value
    memyr = client_memyr.value

    data =     {
        "age": age,
        "clid": client,
        "fname": fname,
        "lname": lname,
        "memberyear": memyr
    }
    json_data = json.dumps(data)

    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/client/{client}"
        headers = {'Content-Type': 'application/json'}
        
        response = requests.put(url, data=json_data, headers=headers)
        if response.status_code == 200:
            response = response.json()
            clid = response['clid']
            update_client_form.layout.display = 'none'
            output.clear_output()
            print('Client ID: ', clid)
            print("First Name: ", fname )
            print("Last Name: ", lname)
            print("Age: ", age)
            print("Memeber Year: ", memyr)
            print('Client Updated')
        else:
            # Print error message if request was unsuccessful
            print(response.text)
            print('Failed to update client')

def delete_client(e):
    client = clid_field.value

    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/client/{client}"
        headers = {'Content-Type': 'application/json'}
        
        response = requests.delete(url)
        if response.status_code == 200:
            response = response.json()
            delete_client_form.layout.display = 'none'
            output.clear_output()
            print(f'Client {client} Deleted' )
        else:
            # Print error message if request was unsuccessful
            print(response.text)
            print('Failed to delete clients')
#________________________________________________________________________________________________________________________________________#

#CREATE HOTEL
def create_hotel(e):
    output.clear_output()
    chid = chid_field.value
    hname = hname_field.value
    hcity =  hcity_field.value

    data =    {
        "chid": chid,
        "hcity": hcity,
        "hname": hname
    }
    json_data = json.dumps(data)
    url = "https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/hotel"
    headers = {'Content-Type': 'application/json'}
    with output:
        response = requests.post(url, data=json_data, headers=headers)
        if response.status_code == 201:
            response = response.json()
            hid = response['hid']
            create_hotel_form.layout.display = 'none'
            output.clear_output()
            print('Hotel ID: ', hid)
            print("Chain ID: ", chid )
            print("Hotel Name: ", hname)
            print("Hotel City: ", hcity)
            print('Hotel Created')
        else:
            print( response.text)
            print('Failed to create Hotel')

#UPDATE HOTEL
# Fetch Hotel by ID
def fetch_hotel_byId(e):
    hotel = hid_field.value
    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/hotel/{hotel}"
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            # Update the fields with the fetched data
            hid = data['hid']
            hname = data['hname']
            chid_ = data['chid']
            hcity = data['hcity']
            output.clear_output()
            print('Hotel Information')
            print('Hotel ID: ', hid)
            print("Chain ID: ", chid_)
            print("Hotel Name: ", hname)
            print("Hotel City: ", hcity)
        else:
            print(response.text)
            print(f"Hotel with ID {hotel} not found.")

# Update Hotel
def update_hotel(e):
    hid = hid_field.value
    chid = chid_field.value
    hname = hname_field.value
    hcity = hcity_field.value

    data = {
        "chid": chid,
        "hid": hid,
        "hcity": hcity,
        "hname": hname
    }
    json_data = json.dumps(data)

    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/hotel/{hid}"
        headers = {'Content-Type': 'application/json'}
        
        response = requests.put(url, data=json_data, headers=headers)
        if response.status_code == 200:
            response = response.json()
            hid = response['hid']
            update_hotel_form.layout.display = 'none'
            output.clear_output()
            print('Hotel ID: ', hid)
            print("Chain ID: ", chid)
            print("Hotel Name: ", hname)
            print("Hotel City: ", hcity)
            print('Hotel Updated')
        else:
            print(response.text)
            print('Failed to update hotel')

# Delete Hotel
def delete_hotel(e):
    hid = hid_field.value

    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/hotel/{hid}"
        
        response = requests.delete(url)
        if response.status_code == 200:
            response = response.json()
            delete_hotel_form.layout.display = 'none'
            output.clear_output()
            print(f'Hotel {hid} Deleted')
        else:
            print(response.text)
            print('Failed to delete Hotel')

#________________________________________________________________________________________________________________________________________#
#CREATE Employee
def create_employee(e):
    output.clear_output()
    empl_hid = hid_field.value
    fname = employee_fname.value
    lname = employee_lname.value
    age = employee_age.value
    position = employee_position.value
    salary = employee_salary.value

    data =    {
    "age": age,
    "fname": fname,
    "hid": empl_hid,
    "lname": lname,
    "position": position,
    "salary": salary
    }
    json_data = json.dumps(data)
    url = "https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/employee"
    headers = {'Content-Type': 'application/json'}
    with output:
        response = requests.post(url, data=json_data, headers=headers)
        if response.status_code == 201:
            response = response.json()
            eid = response['eid']
            fullname = f'{fname} {lname}'
            create_employee_form.layout.display = 'none'
            print('Employee ID: ', eid)
            print("Hotel ID: ", empl_hid )
            print("Employee Name: ", fullname)
            print("Age: ", age)
            print('Position', position)
            print('Salary', salary)
        else:
            print( response.text)
            print('Failed to create Employee')

#UPDATE EMPLOYEE
def fetch_employee_byId(e):
    employee = eid_field.value
    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/employee/{employee}"
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            # Update the fields with the fetched data

            age = data['age']
            fname = data['fname']
            eid = data['eid']
            hid = data['hid']
            lname = data['lname']
            pos = data['position']
            sal = data['salary']
            output.clear_output()
            fullname = f'{fname} {lname}'
            print('Employee ID: ', eid)
            print("Hotel ID: ", hid )
            print("Employee Name: ", fullname)
            print("Age: ", age)
            print('Position', pos)
            print('Salary', sal)
        else:
            print(response.text)
            print(f"Employee with ID {eid} not found.")

# Update Hotel
def update_employee(e):
    eid = eid_field.value
    hid = hid_field.value
    fname = employee_fname.value
    lname = employee_lname.value
    age = employee_age.value
    position = employee_position.value
    salary = employee_salary.value


    data =    {
    "age": age,
    "eid" : eid,
    "fname": fname,
    "hid": hid,
    "lname": lname,
    "position": position,
    "salary": salary
    }
    json_data = json.dumps(data)

    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/employee/{eid}"
        headers = {'Content-Type': 'application/json'}
        
        response = requests.put(url, data=json_data, headers=headers)
        if response.status_code == 200:
            response = response.json()
            eid = response['eid']
            update_employee_form.layout.display = 'none'
            output.clear_output()
            print('Employee ID: ', eid)
            print("Hotel ID: ", hid )
            fullname = f'{fname} {lname}'
            print("Employee Name: ", fullname)
            print("Age: ", age)
            print('Position', position)
            print('Salary', salary)
        else:
            print(response.text)
            print('Failed to update employee')

# Delete Hotel
def delete_employee(e):
    eid = eid_field.value

    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/employee/{eid}"
        
        response = requests.delete(url)
        if response.status_code == 200:
            response = response.json()
            delete_employee_form.layout.display = 'none'
            output.clear_output()
            print(f'Employee with ID: {eid} Deleted')
        else:
            print(response.text)
            print('Failed to delete Employee')

#________________________________________________________________________________________________________________________________________#
#________________________________________________________________________________________________________________________________________#
#CREATE Login
def create_login(e):
    output.clear_output()
    logineid = eid_field.value
    loginusername = login_username.value
    loginpassword = login_password.value

    data =    {
        "eid": logineid,
        "password": loginpassword,
        "username": loginusername
    }
    
    json_data = json.dumps(data)
    url = "https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/login"
    headers = {'Content-Type': 'application/json'}
    with output:
        response = requests.post(url, data=json_data, headers=headers)
        if response.status_code == 201:
            response = response.json()
            lid = response['lid']
            create_login_form.layout.display = 'none'
            print('Login ID: ', lid )
            print("Employee ID: ", logineid )
            print("Username: ", loginusername)
            print('Password: ', loginpassword)
        else:
            print( response.text)
            print('Failed to create Login')
#UPDATE EMPLOYEE
def fetch_login_byId(e):
    lid= lid_field.value
    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/login/{lid}"
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            # Update the fields with the fetched data
            eid = data['eid']
            lid= data['lid']
            user = data['username']
            password = data['password']
            output.clear_output()
            print('Login ID: ', lid )
            print("Employee ID: ", eid )
            print("Username: ", user)
            print('Password: ', password)
        else:
            print(response.text)
            print(f"Login with ID {lid} not found.")

# Update Employee
def update_login(e):
    eid = eid_field.value
    lid= lid_field.value
    user = login_username.value
    password = login_password.value


    data =      {
        "eid": eid,
        "lid": lid,
        "password": password,
        "username": user
    }
    json_data = json.dumps(data)

    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/login/{lid}"
        headers = {'Content-Type': 'application/json'}
        
        response = requests.put(url, data=json_data, headers=headers)
        if response.status_code == 200:
            response = response.json()
            lid = response['lid']
            update_login_form.layout.display = 'none'
            output.clear_output()
            print('Login ID: ', lid )
            print("Employee ID: ", eid )
            print("Username: ", user)
            print('Password: ', password)
        else:
            print(response.text)
            print('Failed to update login')

# Delete Hotel
def delete_login(e):
    lid= lid_field.value

    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/login/{lid}"
        
        response = requests.delete(url)
        if response.status_code == 200:
            response = response.json()
            delete_login_form.layout.display = 'none'
            output.clear_output()
            print(f'Login with ID: {lid} Deleted')
        else:
            print(response.text)
            print('Failed to delete Employee')

#________________________________________________________________________________________________________________________________________#
#________________________________________________________________________________________________________________________________________#
#CREATE Description
def create_room_description(e):
    output.clear_output()
    rname = room_name_field.value
    rtype  = room_name_field.value
    capacity = capacity_field.value
    handicap = handicap_field.value
    

    data =  {
    "capacity": capacity,
    "ishandicap": handicap,
    "rname": rtype,
    "rtype": rname
}
    
    json_data = json.dumps(data)
    url = "https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/roomdescription"
    headers = {'Content-Type': 'application/json'}
    with output:
        response = requests.post(url, data=json_data, headers=headers)
        if response.status_code == 201:
            response = response.json()
            rdid = response['rdid']
            create_room_desc_form.layout.display = 'none'
            print('Room Description ID: ', rdid )
            print("Room Name: ", rname )
            print("Room Type: ", rtype)
            print('Capacity: ', capacity)
            print('isHandicap: ', handicap)
        else:
            print( response.text)
            print('Failed to create Room Description')



#UPDATE
def fetch_room_description_by_id(e):
    rdid = rdid_field.value
    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/roomdescription/{rdid}"
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            # Update the fields with the fetched data
            rname = data['rname']
            rtype = data['rtype']
            capacity = data['capacity']
            handicap = data['ishandicap']
            output.clear_output()
            print('Room Description ID:', rdid)
            print("Room Name:", rname)
            print("Room Type:", rtype)
            print('Capacity:', capacity)
            print('Is Handicap:', handicap)
        else:
            print(response.text)
            print(f"Room Description with ID {rdid} not found.")


def update_room_description(e):
    rdid = rdid_field.value
    rname = room_name_field.value
    rtype = room_type_field.value
    capacity = capacity_field.value
    handicap = handicap_field.value

    data = {
    "capacity": capacity,
    "ishandicap": handicap,
    "rname": rname,
    "rdid" : rdid,
    "rtype": rtype
}

    json_data = json.dumps(data)

    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/roomdescription/{rdid}"
        headers = {'Content-Type': 'application/json'}

        response = requests.put(url, data=json_data, headers=headers)
        if response.status_code == 200:
            response_data = response.json()
            rdid = response_data['rdid']
            update_description_form.layout.display = 'none'
            output.clear_output()
            print('Room Description ID:', rdid)
            print("Room Name:", rname)
            print("Room Type:", rtype)
            print('Capacity:', capacity)
            print('Is Handicap:', handicap)
        else:
            print(response.text)
            print('Failed to update Room Description')

            
def delete_room_description(e):
    rdid = rdid_field.value

    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/roomdescription/{rdid}"

        response = requests.delete(url)
        if response.status_code == 200:
            delete_des_form.layout.display = 'none'
            output.clear_output()
            print(f'Room Description with ID: {rdid} Deleted')
        else:
            print(response.text)
            print('Failed to delete Room Description')

#________________________________________________________________________________________________________________________________________#

#________________________________________________________________________________________________________________________________________#
#CREATE Description
def create_room(e):
    output.clear_output()
    hid_room = hid_field.value
    rdid_room  = room_des_field.value
    rprice = room_price_field.value

    data =  {
    "hid": hid_room,
    "rdid": rdid_room,
    "rprice": rprice
}
    
    json_data = json.dumps(data)
    url = "https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/room"
    headers = {'Content-Type': 'application/json'}
    with output:
        response = requests.post(url, data=json_data, headers=headers)
        if response.status_code == 201:
            response = response.json()
            rid = response['rid']
            create_room_form.layout.display = 'none'
            print('Room ID: ', rid )
            print("Room's Hotel: ", hid_room )
            print("Room Description ", rdid_room)
            print('Room Price: ', rprice)
        else:
            print( response.text)
            print('Failed to create Room Description')


#UPDATE 
def fetch_room_by_id(e):
    rid = rid_field.value
    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/room/{rid}"
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            hid_room = data['hid']
            rdid_room = data['rdid']
            rprice = data['rprice']
            output.clear_output()
            print('Room ID:', rid)
            print("Room's Hotel:", hid_room)
            print("Room Description:", rdid_room)
            print('Room Price:', rprice)
        else:
            print(response.text)
            print(f"Room with ID {rid} not found.")

def update_room(e):
    rid = rid_field.value
    hid_room = hid_field.value
    rdid_room = room_des_field.value
    rprice = room_price_field.value

    data = {
        "hid": hid_room,
        "rid": rid,
        "rdid": rdid_room,
        "rprice": rprice
    }

    json_data = json.dumps(data)

    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/room/{rid}"
        headers = {'Content-Type': 'application/json'}

        response = requests.put(url, data=json_data, headers=headers)
        if response.status_code == 200:
            response_data = response.json()
            rid = response_data['rid']
            update_room_form.layout.display = 'none'
            output.clear_output()
            print('Room ID:', rid)
            print("Room's Hotel:", hid_room)
            print("Room Description:", rdid_room)
            print('Room Price:', rprice)
        else:
            print(response.text)
            print('Failed to update Room')


def delete_room(e):
    rid = rid_field.value

    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/room/{rid}"

        response = requests.delete(url)
        if response.status_code == 200:
            delete_room_form.layout.display = 'none'
            output.clear_output()
            print(f'Room with ID: {rid} Deleted')
        else:
            print(response.text)
            print('Failed to delete Room')

#________________________________________________________________________________________________________________________________________#
def check_availability():
    start_date = reserve_startdate_input.value.strftime('%Y-%m-%d') if reserve_startdate_input.value else None
    end_date = reserve_endate_input.value.strftime('%Y-%m-%d') if reserve_endate_input.value else None
    guest = reserve_guest_field.value
    handicap = reserve_handicap_field.value
    hid = reserve_hid_field.value
    data = {
        "guests": guest,
        "hid": hid,
        "ishandicap": handicap,
        "startdate": start_date,
        "enddate": end_date
    }
    
    json_data = json.dumps(data)
    url = "https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/availablerooms"
    headers = {'Content-Type': 'application/json'}
    
    response = requests.post(url, data=json_data, headers=headers)
    
    if response.status_code == 200:
        try:
            output.clear_output()
            return response.json()
        except json.JSONDecodeError:
            print("Failed to decode JSON from response.")
            return None
    else:
        print(f"Failed to fetch data. Status code: {response.status_code}")
        return None

def check_availability_regular():
    start_date = employee_startdate_input.value.strftime('%Y-%m-%d') if employee_startdate_input.value else None
    end_date = employee_enddate_input.value.strftime('%Y-%m-%d') if employee_enddate_input.value else None
    guest = employee_guest_field.value
    handicap = employee_handicap_field.value

    hid_val = hid
    data = {
        "guests": guest,
        "hid": hid,
        "ishandicap": handicap,
        "startdate": start_date,
        "enddate": end_date
    }
    
    json_data = json.dumps(data)
    url = "https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/availablerooms"
    headers = {'Content-Type': 'application/json'}
    
    response = requests.post(url, data=json_data, headers=headers)
    
    if response.status_code == 200:
        try:
            output.clear_output()
            return response.json()
        except json.JSONDecodeError:
            print("Failed to decode JSON from response.")
            return None
    else:
        print(f"Failed to fetch data. Status code: {response.status_code}")
        return None


def create_room_unavailable(e):
    output.clear_output()
    rid = rid_field.value
    start_date = startdate_input.value.strftime('%Y-%m-%d') if startdate_input.value else None
    end_date = endate_input.value.strftime('%Y-%m-%d') if endate_input.value else None

    if not rid or not start_date or not end_date:
        print("Please fill in all fields.")
        return
    
    # Validate the dates to ensure they are in the correct format
    try:
        # Ensure dates are strings
        assert isinstance(start_date, str)
        assert isinstance(end_date, str)
        # Further validation could be added here to check the date format more rigorously
    except AssertionError:
        print("Invalid data types provided. Dates must be in YYYY-MM-DD format.")
        return
    
    try:
        rid = int(rid)
    except ValueError:
        print("Room ID must be an integer.")
        return
    
    data = {
        'rid': rid,
        'startdate': start_date,
        'enddate': end_date
    }

    json_data = json.dumps(data)

    with output:
        url = "https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/roomunavailable"
        headers = {'Content-Type': 'application/json'}
        
        response = requests.post(url, data=json_data, headers=headers)
        
        if response.status_code == 201:
            response = response.json()
            ruid = response['ruid']
            create_unavaibale_items.layout.display = 'none'
            # Print created room unavailable with message
            print("Room Unavailable ID: ", ruid)
            print("Room ID: ", rid)
            print("Start Date: ", start_date)
            print("End Date: ", end_date)
            print('Room unavailable created successfully!')
        else:
            # Print the response content for debugging
            print( response.text)
            print('Failed to create room unavailable')


def fetch_room_unavailable_by_id(e):
    ruid = ruid_field.value
    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/roomunavailable/{ruid}"
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            rid = data['rid']
            start_date = data['startdate']
            end_date = data['enddate']
            output.clear_output()
            print('Room Unavailable ID:', ruid)
            print("Room ID:", rid)
            print("Start Date:", start_date)
            print("End Date:", end_date)
        else:
            print(response.text)
            print(f"Room Unavailable with ID {ruid} not found.")

def update_room_unavailable(e):
    ruid = ruid_field.value
    rid = rid_field.value
    start_date = startdate_input.value.strftime('%Y-%m-%d') if startdate_input.value else None
    end_date = endate_input.value.strftime('%Y-%m-%d') if endate_input.value else None

    data = {

        'rid': rid,
        'ruid': ruid,
        'startdate': start_date,
        'enddate': end_date
    }

    json_data = json.dumps(data)

    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/roomunavailable/{ruid}"
        headers = {'Content-Type': 'application/json'}

        response = requests.put(url, data=json_data, headers=headers)
        if response.status_code == 200:
            response_data = response.json()
            ruid = response_data['ruid']
            update_roomUnv_form.layout.display = 'none'
            output.clear_output()
            print("Room Unavailable ID:", ruid)
            print("Room ID:", rid)
            print("Start Date:", start_date)
            print("End Date:", end_date)
        else:
            print(response.text)
            print('Failed to update Room Unavailable')

def delete_room_unavailable(e):
    ruid = ruid_field.value

    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/roomunavailable/{ruid}"

        response = requests.delete(url)
        if response.status_code == 200:
            delete_roomUnv_form.layout.display = 'none'
            output.clear_output()
            print(f'Room Unavailable with ID: {ruid} Deleted')
        else:
            print(response.text)
            print('Failed to delete Room Unavailable')



#________________________________________________-
#CREATE RESERVE  REGULAR
def create_reserve_regular(selected_room, start_date, end_date,num_guests, clid, payment_re):
    output.clear_output()
    rid = selected_room
    start_date = start_date.strftime('%Y-%m-%d')
    end_date = end_date.strftime('%Y-%m-%d')

    clid_val = clid
    payment = payment_re
    guests = num_guests

    data = {
        'rid': rid,
        'startdate': start_date,
        'enddate': end_date
    }

    json_data = json.dumps(data)

    with output:
        url = "https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/roomunavailable"
        reserve_url = 'https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/reserve'
        headers = {'Content-Type': 'application/json'}
        
        response = requests.post(url, data=json_data, headers=headers)
        
        if response.status_code == 201:
            response = response.json()
            ruid = response['ruid']
            reserve_data = {
                "clid": clid_val,
                "guests": guests,
                "payment":payment,
                "ruid": ruid
            }
            json_data2 = json.dumps(reserve_data)
            reserve_response = requests.post(reserve_url, data=json_data2, headers=headers)
            if reserve_response.status_code == 201:
                create_reserve_form.layout.display = 'none'
                data_response = reserve_response.json()
                reid = data_response['reid'] 
                total_cost = data_response['total_cost']
                print("Reservation ID: ", reid)
                print("Room Unavailable ID: ", ruid)
                print("Client ID: ", clid)
                print("Total Cost: ", total_cost)
                print("Payment Method: ", payment)
                print("Guests: ", guests)
                print('Reservation Created')
            else:
                # Print the response content for debugging
                print(reserve_response.text)
        else:
            # Print the response content for debugging
            print(response.text)
            print('Failed to create room room unavailable')

#UPDATE 
#CREATE RESERVE 
def create_reserve(selected_room, start_date, end_date,num_guests, clid, payment_re):
    output.clear_output()
    rid = selected_room
    start_date = start_date.strftime('%Y-%m-%d')
    end_date = end_date.strftime('%Y-%m-%d')

    clid_val = clid
    payment = payment_re
    guests = num_guests

    data = {
        'rid': rid,
        'startdate': start_date,
        'enddate': end_date
    }

    json_data = json.dumps(data)

    with output:
        url = "https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/roomunavailable"
        reserve_url = 'https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/reserve'
        headers = {'Content-Type': 'application/json'}
        
        response = requests.post(url, data=json_data, headers=headers)
        
        if response.status_code == 201:
            response = response.json()
            ruid = response['ruid']
            reserve_data = {
                "clid": clid_val,
                "guests": guests,
                "payment":payment,
                "ruid": ruid
            }
            json_data2 = json.dumps(reserve_data)
            reserve_response = requests.post(reserve_url, data=json_data2, headers=headers)
            if reserve_response.status_code == 201:
                create_reserve_form.layout.display = 'none'
                data_response = reserve_response.json()
                reid = data_response['reid'] 
                total_cost = data_response['total_cost']
                print("Reservation ID: ", reid)
                print("Room Unavailable ID: ", ruid)
                print("Client ID: ", clid)
                print("Total Cost: ", total_cost)
                print("Payment Method: ", payment)
                print("Guests: ", guests)
                print('Reservation Created')
            else:
                # Print the response content for debugging
                print(reserve_response.text)
        else:
            # Print the response content for debugging
            print(response.text)
            print('Failed to create room room unavailable')

#UPDATE 
def fetch_reserve_by_id(e):
    reid = reid_field.value
    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/reserve/{reid}"
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            reid_id = data['reid']
            ruid = data['ruid']
            client_d = data['clid']
            cost = data['total_cost']
            payment = data['payment']
            guest = data['guests']
            output.clear_output()
            print("Reserve ID: ", reid_id)
            print("Room Unavailable ID: ", ruid)
            print("Client ID: ", client_d)
            print("Total Cost: ", cost)
            print("Payment Method: ", payment)
            print("Guests: ", guest)
        else:
            print(response.text)
            print(f"Room with ID {reid} not found.")
def update_reserve(e):
    reid = reid_field.value
    ruid = ruid_field.value
    clid = update_client_field.value
    payment = update_payment_select.value
    guests = reserve_guest_field.value
    cost = cost_field.value

    data = {
        "clid": clid,
        "guests": guests,
        "payment": payment,
        "reid": reid,
        "ruid": ruid,
        "total_cost": cost
    }

    json_data = json.dumps(data)

    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/reserve/{reid}"
        headers = {'Content-Type': 'application/json'}

        response = requests.put(url, data=json_data, headers=headers)
        if response.status_code == 200:
            response_data = response.json()
            reid = response_data['reid']
            update_reserve_form.layout.display = 'none'
            output.clear_output()
            print("Room Unavailable ID: ", ruid)
            print("Client ID: ", clid)
            print("Total Cost: ", cost)
            print("Payment Method: ", payment)
            print("Guests: ", guests)
            print('Reservation Updated')
        else:
            print(response.text)
            print('Reserve Update Failed')

def delete_reserve(e):
    reid = reid_field.value

    with output:
        url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/reserve/{reid}"

        response = requests.delete(url)
        if response.status_code == 200:
            delete_reserve_form.layout.display = 'none'
            output.clear_output()
            print(f'Reserve with ID: {reid} Deleted')
        else:
            print(response.text)
            print('Failed to delete Reserve')

# %%
# Function to fetch reservation data from API and return it
def fetch_least_reserve(hid, eid):
    url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/hotel/{hid}/leastreserve"
    payload = json.dumps({"eid": eid})
    headers = {'Content-Type': 'application/json'}
    response = requests.post(url, data=payload, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print("Failed to fetch data:", response.text)
        return None

# Function to fetch handicap reservation data from API and return it
def fetch_handicap_stat(hid, eid):
    url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/hotel/{hid}/handicaproom"
    payload = json.dumps({"eid": eid})
    headers = {'Content-Type': 'application/json'}
    response = requests.post(url, data=payload, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print("Failed to fetch data:", response.text)
        return None

# Function to fetch credit card reservation data from API and return it
def fetch_credit_cards(hid, eid):
    url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/hotel/{hid}/mostcreditcard"
    payload = json.dumps({"eid": eid})
    headers = {'Content-Type': 'application/json'}
    response = requests.post(url, data=payload, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print("Failed to fetch data:", response.text)
        return None
    

def fetch_highest_paid(hid,eid):
    url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/hotel/{hid}/highestpaid"
    payload = json.dumps({"eid": eid})
    headers = {'Content-Type': 'application/json'}
    response = requests.post(url, data=payload, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print("Failed to fetch data:", response.text)
        return None

def fetch_most_discounts(hid, eid):
    url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/hotel/{hid}/mostdiscount"
    payload = json.dumps({"eid": eid})
    headers = {'Content-Type': 'application/json'}
    response = requests.post(url, data=payload, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print("Failed to fetch data:", response.text)
        return None
def fetch_reserv_type(hid, eid):
    url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/hotel/{hid}/roomtype"
    payload = json.dumps({"eid": eid})
    headers = {'Content-Type': 'application/json'}
    response = requests.post(url, data=payload, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print("Failed to fetch data:", response.text)
        return None
    
def fetch_ratio(hid, eid):
    url = f"https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/hotel/{hid}/leastguests"
    payload = json.dumps({"eid": eid})
    headers = {'Content-Type': 'application/json'}
    response = requests.post(url, data=payload, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print("Failed to fetch data:", response.text)
        return None
# Function to plot reservation counts for handicap rooms
def plot_reservation_counts(data, hid):
    if data is None:
        print("No data to plot")
        return

    room_names = [entry['rname'] for entry in data]
    reservation_counts = [entry['reservation_count'] for entry in data]

    plt.figure(figsize=(10, 6))
    plt.bar(room_names, reservation_counts, color='#677D6A')
    plt.xlabel('Room Name')
    plt.ylabel('Reservation Count')
    plt.title(f'Top 5 Handicap Rooms Reserved in Hotel {hid}')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
    plt.close()  # Close the figure to prevent residual display

# Function to plot least reserved rooms
def plot_least_reserve(data, hid):
    if data is None:
        print("No data to plot")
        return

    room_names = [entry['rname'] for entry in data]
    days_not_available = [entry['DaysNotAvailable'] for entry in data]

    plt.figure(figsize=(10, 6))
    plt.bar(room_names, days_not_available, color='#D6BD98')
    plt.xlabel('Room Name')
    plt.ylabel('Days Not Available')
    plt.title(f'Top 3 rooms that were the least time unavailable of hotel {hid}')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
    plt.close()  # Close the figure to prevent residual display

# Function to plot credit card usage
def plot_credit_cards(data, hid):
    if data is None:
        print("No data to plot")
        return

    client_names = [f"clid: {client['clid']}, Name: {client['fname']} {client['lname']}" for client in data]
    reservations = [entry['Reservations'] for entry in data]
    # plt.show()
    plt.figure(figsize=(10, 6))
    plt.bar(client_names, reservations, color='#677D6A')

    plt.xlabel('Clients')
    plt.ylabel('Reservaions')
    plt.title(f'Top 5 Clients By Reservation with Credit Card in hotel {hid}')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
    plt.close()

def plot_highest_paid(data, hid):
    if data is None:
        print("No data to plot")
        return


    eids = [f"eid: {entry['eid']}, Name: {entry['fname']}  {entry['lname']}" for entry in data]
    salaries = [entry['salary'] for entry in data]

    plt.figure(figsize=(10, 6))
    plt.bar(eids, salaries, color='#D6BD98')

    plt.xlabel('Clients')
    plt.ylabel('Reservaions')
    plt.title(f'Top 3 highest paid regular employees in hotel {hid}')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
    plt.close()


def plot_most_discount(data, hid):
    if data is None:
        print("No data to plot")
        return

    client_names = [f"clid: {client['clid']} | Name: {client['fname']} {client['lname']}" for client in data]
    discounts = [float(client['total_discount']) for client in data]

    fig, ax = plt.subplots(figsize=(10, 6))
    bar_width = 0.35
    index = np.arange(len(client_names))
    opacity = 0.8

    bars = ax.bar(index, discounts, color='#677D6A', alpha=opacity)

    ax.set_xlabel('Clients')
    ax.set_ylabel('Discount')
    ax.set_title(f'Top 5 Clients By Discount Rate in Hotel {hid}')
    ax.set_ylim(bottom=0)
    ax.set_xticks(index)
    ax.set_xticklabels(client_names, rotation=45, ha='right')

    # Add exact float numbers as text labels above each bar
    for bar, discount in zip(bars, discounts):
        ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{discount:.2f}', ha='center', va='bottom')

    plt.tight_layout()
    plt.show()
    # Clear previous plot
    plt.close()

def plot_reserv_type(data, hid):
    if data is None:
        print("No data to plot")
        return
    
    room_types = [entry['Room_Type'] for entry in data] 
    total_reservations = [round(entry['total_reservations'], 2) for entry in data]  # Round to two decimal places

    plt.figure(figsize=(10, 6))  # Increase figure size for more spacious plot
    bars = plt.bar(room_types, total_reservations, color='#D6BD98')
    plt.xlabel('Room Type')
    plt.ylabel('Total Reservations')
    plt.title(f'Total Reservation By Room Type in hotel {hid}')
    plt.xticks(rotation=45, ha='right')
    
    # Add text labels to the bars with proper spacing
    for bar, room_type, total_reservation in zip(bars, room_types, total_reservations):
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 10, f"Room Type: {room_type}\nTotal Reservations: {total_reservation}", ha='center', va='bottom', fontsize=8)

    plt.tight_layout()
    plt.show()
def plot_ratio(data, hid):
    if data is None or len(data) == 0:
        print("No data to plot")
        return

    room_ids = [str(hotel['rid']) for hotel in data]
    ratios = [float(hotel['guest_to_capacity_ratio']) for hotel in data]

    fig, ax = plt.subplots(figsize=(10, 6))  # Increase figure size for better readability
    bars = ax.barh(room_ids, ratios, color='#677D6A')

    ax.set_xlabel('Guest-To-Capacity Ratio')
    ax.set_ylabel('Room ID')
    ax.set_title(f'Top Rooms Reserved With The Least Guest-To-Capacity Ratio of Hotel {hid}')

    # Adding value labels on the bars
    for bar in bars:
        ax.text(bar.get_width(), bar.get_y() + bar.get_height()/2, round(bar.get_width(), 3), 
                va='center', ha='left', fontsize=9)

    plt.tight_layout()  # Adjust layout to fit labels
    plt.show()
    plt.clf()

# %%
def fetch_revenue_data(eid):
    url = "https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/most/revenue" 
    payload = json.dumps({"eid": eid})
    headers = {'Content-Type': 'application/json'}
    response = requests.post(url, data=payload, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print("Failed to fetch data:", response.text)
        return None
def plot_revenue_data(data):
    if data is None:
        print("No data to plot")
        return
    
    chain_name = [entry['cname'] for entry in data]
    total_revenue = [entry['total_revenue'] for entry in data]

    plt.figure(figsize=(10, 6))
    bars = plt.bar(chain_name, total_revenue, color='#50B498', width = 0.6)
    plt.xlabel('Chain')
    plt.ylabel('Total Revenue')
    plt.title('Top 3 chains with the highest total revenue')
    plt.xticks(rotation=45, ha='right')
    
    # Adjusting y-axis scale to accommodate larger revenue values
    plt.ylim(min(total_revenue) * 0.9, max(total_revenue) * 1.1)

    # Annotate bars with revenue values
    for bar, revenue in zip(bars, total_revenue):
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f"${revenue:,.2f}",
                 ha='center', va='bottom')

    plt.tight_layout()
    plt.show()
    plt.close()



# PAYMENT METHODS
def fetch_payment_method(eid):
    url = "https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/paymentmethod" 
    payload = json.dumps({"eid": eid})
    headers = {'Content-Type': 'application/json'}
    response = requests.post(url, data=payload, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print("Failed to fetch data:", response.text)
        return None
def plot_payment(data):
    if data is None:
        print("No data to plot")
        return
    
    name = [entry['payment'] for entry in data]
    total_revenue = [float(entry['reservation_percentage']) for entry in data]

    plt.figure(figsize=(10, 6))
    plt.pie(total_revenue, labels=name, autopct='%1.1f%%', startangle=140)
    plt.title('Total reservation percentage by payment method')
    plt.axis('equal')


    plt.tight_layout()
    plt.show()
    plt.close()

def fetch_least_rooms(eid):
    url = "https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/least/rooms" 
    payload = json.dumps({"eid": eid})
    headers = {'Content-Type': 'application/json'}
    response = requests.post(url, data=payload, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print("Failed to fetch data:", response.text)
        return None
    
def plot_least_rooms(data):
    if data is None:
        print("No data to plot")
        return
    
    hotel_names = [entry['chid'] for entry in data]
    total_capacities = [entry['total_rooms'] for entry in data]

    plt.figure(figsize=(10, 6))
    bars = plt.bar(hotel_names, total_capacities, color='#50B498', width = 0.3)
    plt.xlabel('Chains')
    plt.ylabel('Total Rooms')
    plt.title('Top 3 hotel’s chain with the least rooms.')
    plt.xticks(rotation=45, ha='right')
    for bar, capacity in zip(bars, total_capacities):
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(capacity), ha='center', va='bottom')

    plt.tight_layout()
    plt.tight_layout()
    plt.show()
    plt.close()

def fetch_most_capacity_data(eid):
    url = "https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/most/capacity" 
    payload = json.dumps({"eid": eid})
    headers = {'Content-Type': 'application/json'}
    response = requests.post(url, data=payload, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print("Failed to fetch data:", response.text)
        return None
def plot_most_capacity(data):
    if data is None:
        print("No data to plot")
        return
    
    hotel_names = [entry['hname'] for entry in data]
    total_capacities = [entry['total_capacity'] for entry in data]

    plt.figure(figsize=(10, 6))
    plt.bar(hotel_names, total_capacities, color='#9CDBA6')
    plt.xlabel('Hotel')
    plt.ylabel('Total Capacity')
    plt.title('Top 5 hotels with the most client capacity')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
    plt.close()

    
def fetch_most_reservations(eid):
    url = "https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/most/reservation" 
    payload = json.dumps({"eid": eid})
    headers = {'Content-Type': 'application/json'}
    response = requests.post(url, data=payload, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print("Failed to fetch data:", response.text)
        return None
    

def plot_most_reservations(data):
    if data is None:
        print("No data to plot")
        return
    
    hotel_names = [f"{entry['hid']} - {entry['hname']}" for entry in data]
    total_capacities = [entry['total_reservation'] for entry in data]

    plt.figure(figsize=(10, 6))
    bars = plt.bar(hotel_names, total_capacities, color='#50B498', width = 0.3)
    plt.xlabel('Hotels')
    plt.ylabel('Total Reserve')
    plt.title('Top 10% of the hotels that had the most reservations')
    plt.xticks(rotation=45, ha='right')
    for bar, capacity in zip(bars, total_capacities):
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(capacity), ha='center', va='bottom')

    plt.tight_layout()
    plt.tight_layout()
    plt.show()
    plt.close()




def fetch_most_profit_month(eid):
    url = "https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/most/profitmonth" 
    payload = json.dumps({"eid": eid})
    headers = {'Content-Type': 'application/json'}
    response = requests.post(url, data=payload, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print("Failed to fetch data:", response.text)
        return None
    

def plot_most_profit(data):
    if data is None:
        print("No data to plot")
        return
   
    chain_ids = sorted(list(set(entry['chid'] for entry in data)))

    months = sorted(list(set(int(entry['reservation_month']) for entry in data)))
    month_names = {
        1: "January", 2: "February", 3: "March", 4: "April",
        5: "May", 6: "June", 7: "July", 8: "August",
        9: "September", 10: "October", 11: "November", 12: "December"
    }
    profit_counts = np.zeros((len(chain_ids), len(months)))
    for entry in data:
        chain_index = chain_ids.index(entry['chid'])
        month_index = months.index(int(entry['reservation_month']))
        profit_counts[chain_index, month_index] = entry['total_reservations']
    plt.figure(figsize=(10, 6))
    width = 0.2
    for i, chain_id in enumerate(chain_ids):
        plt.bar(np.arange(len(months)) + i * width, profit_counts[i], width=width, label=f'Chain ID {chain_id}')
    plt.xlabel('Month')
    plt.ylabel('Total Reservations')
    plt.title('Total Reservations by Chain ID and Month')
    plt.xticks(np.arange(len(months)) + width * (len(chain_ids) - 1) / 2, [month_names[month] for month in months])
    plt.legend()
    plt.tight_layout()
    plt.show()
    plt.close()

# %%
output = w.Output()
def show_home(event):
    welcome_form.layout.display = 'none'
    login_form.layout.display = 'none'
    regular_options.layout.display = ''
    hid_form.layout.display = 'none'
    supervisor_options.layout.display = 'none'
    admin_options.layout.display = 'none'


def show_sup(event):
    welcome_form.layout.display = 'none'
    login_form.layout.display = 'none'
    regular_options.layout.display = 'none'
    hid_form.layout.display = 'none'
    supervisor_options.layout.display = ''
def show_admin(event):
    welcome_form.layout.display = 'none'
    login_form.layout.display = 'none'
    regular_options.layout.display = 'none'
    hid_form.layout.display = 'none'
    supervisor_options.layout.display = 'none'
    admin_options.layout.display = ''

def toggle_login(event):
    welcome_form.layout.display = 'none'
    login_form.layout.display = ''
    
def toggle_sigup(e):
    welcome_form.layout.display = 'none'
    login_form.layout.display = 'none'
    signup_create_employee_form.layout.display = ''

def toggle_welcome(e):
    welcome_form.layout.display = ''
    login_form.layout.display = 'none'
    signup_create_employee_form.layout.display = 'none'
global position
def toggle_options_sup(event):
    if position == 'Supervisor':
        welcome_form.layout.display = 'none'
        login_form.layout.display = 'none'
        regular_options.layout.display = 'none'
        create_unavaibale_items.layout.display ='none'
        hid_form.layout.display = '' 
        global_nest.layout.display = 'none'
    elif position == "Regular":
        welcome_form.layout.display = 'none'
        login_form.layout.display = 'none'
        regular_options.layout.display = ''
        create_unavaibale_items.layout.display ='none'
        hid_form.layout.display = '' 
        global_nest.layout.display = 'none'  
    elif position == "Administrator":
        welcome_form.layout.display = 'none'
        login_form.layout.display = 'none'
        regular_options.layout.display = 'none'
        create_unavaibale_items.layout.display ='none'
        hid_form.layout.display = '' 
        global_nest.layout.display = 'none'  


def toggle_supervisor_unv(event):
    welcome_form.layout.display = 'none'
    login_form.layout.display = 'none'
    regular_options.layout.display = 'none'
    hid_form.layout.display = 'none' 
    tab_nest.layout.display = 'none'
    create_unavaibale_items.layout.display =''


def toggle_regular_resr(event):
    welcome_form.layout.display = 'none'
    login_form.layout.display = 'none'
    regular_options.layout.display = ''
    hid_form.layout.display = 'none' 
    tab_nest.layout.display = 'none'
    create_regular_reserve_form.layout.display = ''

def toggle_regular_local(event):
    welcome_form.layout.display = 'none'
    login_form.layout.display = 'none'
    regular_options.layout.display = ''
    create_unavaibale_items.layout.display ='none'
    hid_form.layout.display = '' 
    global_nest.layout.display = 'none'
    create_regular_reserve_form.layout.display = 'none'
           
# Attach the toggle function to the Log In button
show_LogIn.on_click(toggle_login)
show_signUp.on_click(toggle_sigup)


show_local_stats.on_click(toggle_options_sup)
confirm_button.on_click(create_tabs)



show_global_stats.on_click(global_tabs)
create_unavailable_button.on_click(toggle_supervisor_unv)
create_unavailable_button_confirm.on_click(create_room_unavailable)

menu_create_reservation.on_click(toggle_regular_resr)
show_local_stats_regular.on_click(toggle_regular_local)
create_chain_button.on_click(create_chain)
create_client_button.on_click(create_client)
create_hotel_button.on_click(create_hotel)
create_employee_button.on_click(create_employee)
create_login_button.on_click(create_login)
create_room_desc_button.on_click(create_room_description)
create_room_button.on_click(create_room)



chain_info_button.on_click(fetch_chain_byId)
update_chain_button.on_click(update_chain)
delete_chain_button.on_click(delete_chain)


client_info_button.on_click(fetch_client_byId)
update_client_button.on_click(update_client)
delete_client_button.on_click(delete_client)

hotel_info_button.on_click(fetch_hotel_byId)
update_hotel_button.on_click(update_hotel)
delete_hotel_button.on_click(delete_hotel)

employee_info_button.on_click(fetch_employee_byId)
update_employee_button.on_click(update_employee)
delete_employee_button.on_click(delete_employee)



login_info_button.on_click(fetch_login_byId)
update_login_button.on_click(update_login)
delete_login_button.on_click(delete_login)


description_info_button.on_click(fetch_room_description_by_id)
update_description_button.on_click(update_room_description)
delete_des_button.on_click(delete_room_description)

room_info_button.on_click(fetch_room_by_id)
update_room_button.on_click(update_room)
delete_room_button.on_click(delete_room)

roomUn_info_button.on_click(fetch_room_unavailable_by_id)
update_roomUnv_button.on_click(update_room_unavailable)
delete_roomUnv_button.on_click(delete_room_unavailable)
def update_dropdown(e):
    with output:
        output.clear_output()
        data = check_availability()  # Fetch data
        
        if data:
            # Ensure data is a list of dictionaries
            if isinstance(data, list):
                options = []
                for room in data:
                    option_text = f"{room['rname']} - {room['rtype']} - ${room['rprice']:.2f} (ID: {room['rid']})"
                    options.append((option_text, room['rid']))
                
                available_rooms_select.options = options
                available_box.layout.display = 'flex'
            else:
                print("Data format is not as expected.")
        else:
            print("No data available.")
def update_employee_dropdown(e):
    with output:
        output.clear_output()
        data = check_availability_regular()  # Fetch data
        
        if data:
            # Ensure data is a list of dictionaries
            if isinstance(data, list):
                options = []
                for room in data:
                    option_text = f"{room['rname']} - {room['rtype']} - ${room['rprice']:.2f} (ID: {room['rid']})"
                    options.append((option_text, room['rid']))
                
                empl_rooms_select.options = options
                empl_available_box.layout.display = 'flex'
            else:
                print("Data format is not as expected.")
        else:
            print("No data available.")


check_available_button.on_click(update_dropdown)
empl_available_button.on_click(update_employee_dropdown)
def on_reg_reserve(e):
    try:
        hid_val = hid
        start_date = employee_startdate_input.value
        end_date = employee_enddate_input.value
        num_guests = employee_guest_field.value
        selected_room = empl_rooms_select.value
        clid = employee_client_field.value
        payment_re = empl_payment_select.value

        
        
        if None in [hid_val, start_date, end_date, num_guests, selected_room,clid,payment_re]:
            print("Please fill in all fields")
            return

        # Call your function to create a reservation
        create_reserve_regular(selected_room, start_date, end_date,num_guests, clid, payment_re)
        
    except Exception as e:
        print(f"An error occurred: {e}")
def on_reserve_button_click(b):
    try:
        hid = reserve_hid_field.value
        start_date = reserve_startdate_input.value
        end_date = reserve_endate_input.value
        num_guests = reserve_guest_field.value
        selected_room = available_rooms_select.value
        clid = reserve_client_field.value
        payment_re = payment_select.value

        
        
        if None in [hid, start_date, end_date, num_guests, selected_room,clid,payment_re]:
            print("Please fill in all fields")
            return

        # Call your function to create a reservation
        create_reserve(selected_room, start_date, end_date,num_guests, clid, payment_re)
        
    except Exception as e:
        print(f"An error occurred: {e}")

reserve_room_button.on_click(on_reserve_button_click)
employee_room_button.on_click(on_reg_reserve)
update_reserve_button.on_click(update_reserve)
delete_reserve_button.on_click(delete_reserve)
reserve_info_button.on_click(fetch_reserve_by_id)
return_button.on_click(toggle_welcome)
# Display the welcome form initially
display(welcome_form, login_form, regular_options,supervisor_options, 
        admin_options,hid_form, tab_nest, global_nest, create_unavaibale_items, 
        create_chain_form, create_client_form, create_hotel_form,create_employee_form,
        create_login_form, create_room_desc_form, create_room_form,update_chain_form, delete_chain_form, update_client_form, delete_client_form,
        update_hotel_form, delete_hotel_form, update_employee_form,delete_employee_form,update_login_form,delete_login_form, update_description_form, delete_des_form, 
        update_roomUnv_form, delete_roomUnv_form, update_room_form, delete_room_form,
        signup_create_employee_form, signup_create_login_form, create_reserve_form, delete_reserve_form, update_reserve_form, create_regular_reserve_form)


def sigup(e):
    global eid
    global position
    global hid
    with output:
        display(create_employee_form)


def login(e):
    global eid
    global position
    global hid
    with output:
        username = username_input.value
        password = password_input.value
        url = "https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/login/home"
        data = {
            'username': username,
            'password': password
        } 
        headers = {'Content-Type': 'application/json'}
        response = requests.post(url, json=data, headers=headers)
        if response.status_code ==200:
            data = response.json()
            username = data.get('username')
            password = data.get('password')
            eid = data.get('eid')
            hid = data.get('hid')
            position = data.get('position')
            print('Login successful')
            print(position)
            print(eid)
            username_input.close()
            password_input.close()
            if position == 'Supervisor':
                login_Button.on_click(lambda e: show_sup(e))
            elif position =="Regular":
                login_Button.on_click(lambda e: show_home(e))
            elif position=="Administrator":
                login_Button.on_click(lambda e: show_admin(e))

        else:
            print(response.text)
            print('Invalid username or password')


login_Button.on_click(lambda e: login(e))
#FOR THE SIGNUP 
def signup_create_employee(e):
    output.clear_output()
    empl_hid = signup_hid_field.value
    fname = signup_fname.value
    lname = signup_lname.value
    age = signup_age.value
    position = signup_position.value
    salary = signup_salary.value

    data =    {
    "age": age,
    "fname": fname,
    "hid": empl_hid,
    "lname": lname,
    "position": position,
    "salary": salary
    }
    json_data = json.dumps(data)
    url = "https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/employee"
    headers = {'Content-Type': 'application/json'}
    with output:
        response = requests.post(url, data=json_data, headers=headers)
        if response.status_code == 201:
            response = response.json()
            eid = response['eid']
            fullname = f'{fname} {lname}'
            signup_create_employee_form.layout.display = 'none'
            signup_create_login_form.layout.display = 'flex'
            print('Employee ID: ', eid)
            print("Hotel ID: ", empl_hid )
            print("Employee Name: ", fullname)
            print("Age: ", age)
            print('Position', position)
            print('Salary', salary)
        else:
            print( response.text)
            print('Failed to create Employee')

def signup_create_login(e):
    output.clear_output()
    logineid = signup_eid_field.value
    loginusername = signup_login_username.value
    loginpassword = signup_login_password.value

    data =    {
        "eid": logineid,
        "password": loginpassword,
        "username": loginusername
    }
    
    json_data = json.dumps(data)
    url = "https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/login"
    headers = {'Content-Type': 'application/json'}
    with output:
        response = requests.post(url, data=json_data, headers=headers)
        if response.status_code == 201:
            response = response.json()
            lid = response['lid']
            create_login_form.layout.display = 'none'
            print('Login ID: ', lid )
            print("Employee ID: ", logineid )
            print("Username: ", loginusername)
            print('Password: ', loginpassword)
        else:
            print( response.text)
            print('Failed to create Login')


def signup_login(e):
    global eid
    global position
    global hid
    with output:
        username = signup_login_username.value
        password = signup_login_password.value
        url = "https://hotel-analytical-system-dbstr-f8af34ea4353.herokuapp.com/dbstruggles/login/home"
        data = {
            'username': username,
            'password': password
        }
        response = requests.get(url, json=data)
        if response.status_code ==200:
            data = response.json()
            username = data.get('username')
            password = data.get('password')
            hid = data.get('hid')
            eid = data.get('eid')
            position = data.get('position')
            print('Login successful')
            signup_login_username.close()
            signup_login_password.close()
            output.clear_output()
            signup_create_login_form.layout.display = 'none'
            if position == 'Supervisor':
                signup_login_button.on_click(lambda e: show_sup(e))
            elif position =="Regular":
                signup_login_button.on_click(lambda e: show_home(e))
            elif position=="Administrator":
                signup_login_button.on_click(lambda e: show_admin(e))

        else:
         print('Invalid username or password')
signup_create_employee_button.on_click(signup_create_employee)
signup_create_login_button.on_click(signup_create_login)
signup_login_button.on_click(lambda e: signup_login(e))

display(output)
